# %%
import json
import re
from pathlib import Path
from typing import List, Dict, Set, Tuple
import pandas as pd

# %%
def load_orders_from_jsons(json_paths: List[str]) -> List[Dict]:
    orders = []
    for path in json_paths:
        with open(path, "r", encoding="utf-8") as f:
            data = json.load(f)
            if isinstance(data, list):
                orders.extend(data)
            else:
                orders.append(data)
    return orders

# %%
def extract_raw_menu_entries_from_orders(orders: List[Dict]) -> List[Dict]:
    extracted = []

    for order in orders:
        raw_event = order.get("raw_event", {})
        raw_payload = raw_event.get("raw_payload", {})
        properties = raw_payload.get("properties", {})

        # Order items
        items = properties.get("OrderItem", [])
        for item in items:
            extracted.append({
                "raw_name": item.get("name", "").strip(),
                "description": None,
                "weight": None
            })

            # Addons
            addons = item.get("addon", [])
            for addon in addons:
                extracted.append({
                    "raw_name": addon.get("name", "").strip(),
                    "description": None,
                    "weight": None
                })

    return extracted

# %%
def fix_html_entities(text):
    """Fix HTML entities like &amp; -> &"""
    return text.replace('&amp;', '&')

def fix_typos(name):
    """Fix common typos in item names"""
    # Fix "Eggles" -> "Eggless"
    name = re.sub(r'\bEggles\b', 'Eggless', name)
    
    # Fix Boston Cream Piec -> Boston Cream Pie
    name = re.sub(r'\bBoston Cream Piec\b', 'Boston Cream Pie', name)
    
    # Fix Bean-to-bar capitalization variations
    name = re.sub(r'\bBean[- ]to[- ]bar\b', 'Bean-to-Bar', name, flags=re.IGNORECASE)
    name = re.sub(r'\bBean To Bar\b', 'Bean-to-Bar', name, flags=re.IGNORECASE)
    
    # Fix "Chocolate Dark" -> "Dark Chocolate" (word order)
    name = re.sub(r'\bChocolate Dark\b', 'Dark Chocolate', name)
    
    # Fix double "Ice Cream Ice Cream"
    name = re.sub(r'\bIce Cream Ice Cream\b', 'Ice Cream', name)
    
    # Fix D&n -> D&N (D&N Traditional Plum Cake)
    name = re.sub(r'\bD&n\b', 'D&N', name)
    
    # Fix "Fig Orange" -> "Fig & Orange" (missing ampersand)
    name = re.sub(r'\bFig Orange\b', 'Fig & Orange', name)
    
    # Fix "Cherry & Chocolate" without "Fudge" -> add "Fudge" to match full name
    # Based on data, the full ice cream name is "Cherry & Chocolate Fudge Ice Cream"
    # This applies to both regular and Eggless versions
    if 'Cherry & Chocolate' in name and 'Fudge' not in name:
        name = name.replace('Cherry & Chocolate', 'Cherry & Chocolate Fudge')
    
    # Fix "Chocolate & Orange With Alcohol" -> standardize naming
    if 'Chocolate & Orange With Alcohol' in name:
        name = name.replace('Chocolate & Orange With Alcohol', 'Chocolate & Orange (Contains Alcohol) Ice Cream')
        # Remove duplicate "Ice Cream" if present
        name = name.replace('Ice Cream Ice Cream', 'Ice Cream')
    
    # Remove trailing parenthesis if incomplete (like "Mini Tub" without closing)
    name = re.sub(r'\s*\([^)]*$', '', name)
    
    return name.strip()

# %%
def normalize_name(raw_name, description, weight):
    """Extract and normalize the clean item name"""
    name = fix_html_entities(raw_name)
    name = fix_typos(name)
    
    # Remove variant info from name (things in parentheses at end)
    variant_patterns = [
        r'\s*\(Family Tub\)?',
        r'\s*\(Junior Scoop\)?',
        r'\s*\(Mini [Tt]ub\)?',
        r'\s*\(Regular Scoop\)?',
        r'\s*\(Regular Tub\)?',
        r'\s*\(Perfect Plenty[^)]*\)?',
        r'\s*\(160gm[s]?\)',  # Handle (160gm) or (160gms)
        r'\s*\(2\s*pc[s]?\)',  # Handle (2pcs)
        r'\s*\(1\s*pc[s]?\)',  # Handle (1pcs)
        r'\s*\(eggless\)',  # Handle (eggless) suffix
    ]
    for pattern in variant_patterns:
        name = re.sub(pattern, '', name, flags=re.IGNORECASE)
    
    # Remove size suffixes from name
    name = re.sub(r'\s+200ml$', '', name, flags=re.IGNORECASE)
    name = re.sub(r'\s+300ml$', '', name, flags=re.IGNORECASE)
    name = re.sub(r'\s+160gm$', '', name, flags=re.IGNORECASE)
    name = re.sub(r'\s+Small Scoop$', '', name, flags=re.IGNORECASE)
    
    # Handle "Chocolate & Orange" with alcohol
    if 'Chocolate & Orange' in name and description and 'alcohol' in description.lower():
        name = 'Chocolate & Orange (Contains Alcohol) Ice Cream'
    elif 'Chocolate & Orange With Alcohol' in name:
        name = 'Chocolate & Orange (Contains Alcohol) Ice Cream'
    
    # Add "Ice Cream" suffix for ice cream items that are missing it
    ice_cream_items_without_suffix = [
        'Cakes & Cookies',
        'Cherry & Chocolate Fudge',  # Note: "Cherry & Chocolate" gets converted to this in fix_typos
        'Chocolate Overload',
        'Coconut & Pineapple',
        'Coffee Mascarpone',
        'Dates & Chocolate',
        'Dates With Fig & Orange',
        'Fig & Orange',
        'Just Chocolate',
        'Old Fashion Vanilla',
        'Eggless Cherry & Chocolate Fudge',  # Note: converted from "Eggless Cherry & Chocolate"
        'Eggless Chocolate',
        'Eggless Chocolate Overload',
        'Eggless Coconut & Pineapple',
        'Eggless Coffee Mascarpone',
        'Eggless Fig & Orange',
        'Eggless Just Chocolate',
        'Eggless Milk Chocolate',
        'Eggless Paan & Gulkand',
        'Eggless Strawberry Cream Cheese',
    ]
    
    for item in ice_cream_items_without_suffix:
        if name == item or name.startswith(item + ' '):
            if 'Ice Cream' not in name:
                name = item + ' Ice Cream'
            break
    
    # Ensure "Cherry & Chocolate Fudge" stays as is (it's not "Cherry & Chocolate")
    # Already handled by exact match above
    
    return name.strip()

# %%
# Extras
EXTRAS = [
    'Cup',
    'Takeaway Cup',
    'Waffle Cone',
    'Butter Waffle Cone',
    'Butter Waffle Cones',
]

# Desserts
DESSERTS = [
    'Boston Cream Pie',
    'Boston Cream Pie Dessert',
    'Brownie Cheesecake',
    'Classic Brownie & Ice Cream With Fudge Sauce',
    'Classic Chocolate Lamington',
    'Classic Tiramisu',
    'D&N Traditional Plum Cake',
    'Fudgy Chocolate Brownie',
    'New York Baked Cheesecake Eggless',
    'Orange & Chocolate Cheesecake',
]

# Combos
COMBOS = [
    'Design Family Pack Of 3 Ice Creams',
    'Design Your Indulgence Duo Ice Creams',
    'Eggless Design Your Indulgence Duo Ice Creams',
    'Half In Half Regular Scoop Combo',
]

def determine_type(name, raw_name):
    """Determine the type of item: Ice Cream, Dessert, Drinks, Extra, Combo"""
    
    # Check extras
    for extra in EXTRAS:
        if extra.lower() in name.lower() or extra.lower() in raw_name.lower():
            return 'Extra'
    
    # Check desserts
    for dessert in DESSERTS:
        if dessert.lower() in name.lower() or dessert.lower() in raw_name.lower():
            return 'Dessert'
    
    # Check combos
    for combo in COMBOS:
        if combo.lower() in name.lower() or combo.lower() in raw_name.lower():
            return 'Combo'
    
    # Default to Ice Cream for most items
    return 'Ice Cream'

# %%
def determine_variant(raw_name, description, weight):
    """Determine the variant based on name, description, and weight"""
    
    raw_lower = raw_name.lower()
    desc_lower = (description or '').lower()
    
    # Check for explicit variant in name
    if '(family tub' in raw_lower or 'family tub' in desc_lower:
        return 'FAMILY_TUB_500GMS'
    
    if '(junior scoop' in raw_lower or desc_lower == 'junior scoop':
        return 'JUNIOR_SCOOP_60GMS'
    
    if '(mini tub' in raw_lower or 'mini tub' in desc_lower:
        return 'MINI_TUB_160GMS'
    
    if '(regular scoop' in raw_lower or desc_lower == 'regular scoop':
        return 'REGULAR_SCOOP_120GMS'
    
    if '(regular tub' in raw_lower or 'regular tub' in desc_lower:
        if '300ml' in desc_lower or '300ml' in raw_lower:
            return 'REGULAR_TUB_300ML'
        return 'REGULAR_TUB_220GMS'
    
    if 'small scoop' in raw_lower:
        return 'JUNIOR_SCOOP_60GMS'
    
    # Check for (160gm) pattern in name (common in addon data)
    if '(160gm' in raw_lower:
        return 'MINI_TUB_160GMS'
    
    # Check for piece counts in name (for extras like Butter Waffle Cone)
    if '(2pc' in raw_lower or '(2 pc' in raw_lower:
        return '2_PIECES'
    if '(1pc' in raw_lower or '(1 pc' in raw_lower:
        return '1_PIECE'
    
    # Check for size in description
    if description:
        if '200ml+200ml' in description.lower() or '200+200+200' in description.lower():
            # Combo variant
            if '200+200+200' in description:
                return 'FAMILY_PACK_3X200ML'
            return 'DUO_200ML_200ML'
        
        if '300ml' in description.lower():
            return 'REGULAR_TUB_300ML'
        
        if '200ml' in description.lower():
            return 'MINI_TUB_200ML'
    
    # Check for 200ml in name
    if '200ml' in raw_lower:
        return 'MINI_TUB_200ML'
    
    if '300ml' in raw_lower:
        return 'REGULAR_TUB_300ML'
    
    # Check weight-based inference for standalone entries
    if weight == 500:
        return 'FAMILY_TUB_500GMS'
    elif weight == 220:
        return 'REGULAR_TUB_220GMS'
    elif weight == 160:
        return 'MINI_TUB_160GMS'
    elif weight == 120:
        return 'REGULAR_SCOOP_120GMS'
    elif weight == 60:
        return 'JUNIOR_SCOOP_60GMS'
    
    # Check description for piece counts (desserts/extras)
    if description:
        if '2pc' in desc_lower or '2 pc' in desc_lower:
            return '2_PIECES'
        if '1pc' in desc_lower or '1 pc' in desc_lower:
            return '1_PIECE'
    
    # Default to 1_PIECE for desserts/extras with no other info
    return '1_PIECE'

def handle_special_cases(name, item_type, variant, raw_name, description, weight):
    """Handle special edge cases"""
    
    # Boston Cream Pie - all should be "Boston Cream Pie"
    if 'boston cream pie' in name.lower():
        name = 'Boston Cream Pie'
        item_type = 'Dessert'
    
    # Half In Half Combo
    if 'half in half' in name.lower():
        variant = 'HALF_IN_HALF_REGULAR_SCOOP'
    
    # Butter Waffle Cone/Cones
    if 'butter waffle' in name.lower():
        name = 'Butter Waffle Cone'
        item_type = 'Extra'
    
    # Waffle Cone standalone
    if name.lower() == 'waffle cone':
        item_type = 'Extra'
        variant = '1_PIECE'
    
    # Cup / Takeaway Cup
    if name.lower() in ['cup', 'takeaway cup']:
        item_type = 'Extra'
        variant = '1_PIECE'
    
    return name, item_type, variant

# %%
def build_clean_menu_from_orders(raw_entries: List[Dict]) -> pd.DataFrame:
    records = []

    for entry in raw_entries:
        raw_name = entry["raw_name"]
        if not raw_name:
            continue

        clean_name = normalize_name(raw_name, entry.get("description"), entry.get("weight"))
        item_type = determine_type(clean_name, raw_name)
        variant = determine_variant(raw_name, entry.get("description"), entry.get("weight"))
        name, item_type, variant = handle_special_cases(clean_name, item_type, variant, raw_name, description, weight)
        records.append({
            "name": clean_name,
            "type": item_type,
            "variant": variant,
            "source": "order_json"
        })

    df = pd.DataFrame(records)
    df.drop_duplicates(subset=["name", "type", "variant"], inplace=True)
    return df.sort_values(["name", "type", "variant"])

# %%
import requests
import json
import html
import re
from typing import Optional, List, Dict, Any

BASE_URL = "https://webhooks.db1-prod-dachnona.store/analytics"
API_KEY = "f3e1753aa4c44159fa7218a31cd8db1e"

HEADERS = {
    "X-API-Key": API_KEY,
}

def _safe_json_load(value):
    if value is None:
        return None
    if isinstance(value, (dict, list)):
        return value
    try:
        return json.loads(value)
    except (TypeError, ValueError):
        return value

def fetch_stream_raw(
    endpoint: str,
    limit: int = 500,
    start_cursor: Optional[int] = 0,
) -> List[Dict[str, Any]]:
    results = []
    last_stream_id = start_cursor or 0

    while True:
        params = {
            "limit": limit,
            "cursor": last_stream_id,
        }

        resp = requests.get(
            f"{BASE_URL}/{endpoint}/",
            headers=HEADERS,
            params=params,
            timeout=60,
        )
        resp.raise_for_status()

        payload = resp.json()
        batch = payload.get("data", [])

        if not batch:
            break

        results.extend(batch)
        last_stream_id = batch[-1]["stream_id"]

        if len(batch) < limit:
            break

    return results

records = fetch_stream_raw("orders")

# %%
menu_entries = extract_raw_menu_entries_from_orders(records)

# %%
df = build_clean_menu_from_orders(menu_entries)

# %%
df[df['type'] == 'Ice Cream']['name'].unique()
# Out:
# array(['400 Pidge/porter Delivery Charges',
#        '500 Pidge/porter Delivery Charges', 'Affogato',
#        'Alphonso Mango Ice Cream (Regular)', 'Alphonso Mango Ice Cream)',
#        'Americano', 'Assorted Cookie Duo ( Dark Chocolate + Choco Chip )',
#        'Banoffee Ice Cream', 'Banoffee Ice Cream (120gm))',
#        'Banoffee Ice Cream (220gms))', 'Banoffee Ice Cream (500gms))',
#        'Banoffee Ice Cream (60gm))', 'Banoffee Ice Cream)',
#        'Bean-to-Bar 70% Dark Chocolate Ice Cream',
#        'Bean-to-Bar 70% Dark Chocolate Ice Cream (Family Feast (725ml))',
#        'Bean-to-Bar 70% Dark Chocolate Ice Cream)',
#        'Bean-to-Bar Chocolate 70% Dark Ice Cream',
#        'Bean-to-Bar Chocolate 70% Dark Ice Cream (200ml))',
#        'Bean-to-Bar Chocolate 70% Dark Ice Cream)',
#        'Bean-to-Bar Dark Chocolate Ice Cream',
#        'Bean-to-Bar Dark Chocolate Ice Cream (120gm))',
#        'Bean-to-Bar Dark Chocolate Ice Cream (200ml))',
#        'Bean-to-Bar Dark Chocolate Ice Cream (220gms))',
#        'Bean-to-Bar Dark Chocolate Ice Cream (300ml))',
#        'Bean-to-Bar Dark Chocolate Ice Cream (500gms))',
#        'Bean-to-Bar Dark Chocolate Ice Cream (60gm))',
#        'Bean-to-Bar Dark Chocolate Ice Cream (700ml))',
#        'Bean-to-Bar Dark Chocolate Ice Cream (725ml))',
#        'Bean-to-Bar Dark Chocolate Ice Cream)',
#        "Brownie & Vanilla Ice Cream With Fudge Sauce. It's Classic !",
#        'Cakes & Cookies Ice Cream', 'Cakes & Cookies Ice Cream (120gm))',
#        'Cakes & Cookies Ice Cream (200ml))',
#        'Cakes & Cookies Ice Cream (220gms))',
#        'Cakes & Cookies Ice Cream (300ml))',
#        'Cakes & Cookies Ice Cream (700ml))',
#        'Cakes & Cookies Ice Cream (725ml))',
#        'Cakes & Cookies Ice Cream (Family Feast (725ml))',
#        'Cakes & Cookies Ice Cream)', 'Cappuccino',
#        'Cherry & Chocolate Fudge Ice Cream',
#        'Cherry & Chocolate Fudge Ice Cream (120gm))',
#        'Cherry & Chocolate Fudge Ice Cream (220gms))',
#        'Cherry & Chocolate Fudge Ice Cream (500gms))',
#        'Cherry & Chocolate Fudge Ice Cream (60gm))',
#        'Cherry & Chocolate Fudge Ice Cream)', 'Choco Chunk Cookie',
#        'Chocolate & Orange (Contains Alcohol) Ice Cream',
#        'Chocolate & Orange (Contains Alcohol) Ice Cream)',
#        'Chocolate & Orange (contains Alcohol) (120gm))',
#        'Chocolate & Orange (contains Alcohol) (220gms))',
#        'Chocolate & Orange (contains Alcohol) (60gm))',
#        'Chocolate & Orange (contains Alcohol) Ice Cream (220gms))',
#        'Chocolate & Orange (contains Alcohol) Ice Cream)',
#        'Chocolate & Orange (contains Alcohol))',
#        'Chocolate Overload Ice Cream',
#        'Chocolate Overload Ice Cream (220gms))',
#        'Chocolate Overload Ice Cream (500gms))',
#        'Chocolate Overload Ice Cream)', 'Chocolate Overload)',
#        'Classic Brownie & Vanilla Ice Cream With Fudge Sauce',
#        'Classic Night & Day Duo',
#        'Classic Night & Day Duo Ice Creams (200ml+200ml)',
#        'Coconut & Pineapple Ice Cream',
#        'Coconut & Pineapple Ice Cream (220gms))',
#        'Coconut & Pineapple Ice Cream)', 'Coffee Banana Cheesecake',
#        'Coffee Mascarpone Ice Cream',
#        'Coffee Mascarpone Ice Cream (120gm))',
#        'Coffee Mascarpone Ice Cream (200ml))',
#        'Coffee Mascarpone Ice Cream (220gms))',
#        'Coffee Mascarpone Ice Cream (300ml))',
#        'Coffee Mascarpone Ice Cream (500gms))',
#        'Coffee Mascarpone Ice Cream (60gm))',
#        'Coffee Mascarpone Ice Cream (700ml))',
#        'Coffee Mascarpone Ice Cream (725ml))',
#        'Coffee Mascarpone Ice Cream (Family Feast (725ml))',
#        'Coffee Mascarpone Ice Cream)', 'Cream Cheese Fruit Medley Cake',
#        'Curious Creations Duo',
#        'Curious Creations Duo Ice Creams (200ml+200ml)',
#        'Custom Diwali Cookie Set', 'Customised Ice Cream Cake',
#        'Dark Double Chocolate Cookie', 'Dates & Chocolate Ice Cream',
#        'Dates & Chocolate)', 'Dates Rose & Nuts Ice Cream (120gm))',
#        'Dates Rose & Nuts Ice Cream)',
#        'Dates With Fig & Orange Ice Cream', 'Dates With Fig & Orange)',
#        'Design Your Indulgence Duo',
#        'Egg Based Paan & Gulkand Ice Cream (220gms))',
#        'Egg Based Paan & Gulkand Ice Cream)',
#        'Egg Strawberry Cream Cheese Ice Cream (220gms))',
#        'Egg Strawberry Cream Cheese Ice Cream)',
#        'Eggless Alphanso Mango Ice Cream)', 'Eggless Banoffee Ice Cream',
#        'Eggless Banoffee Ice Cream (200ml))',
#        'Eggless Banoffee Ice Cream (220gms))',
#        'Eggless Banoffee Ice Cream (300ml))',
#        'Eggless Banoffee Ice Cream (700ml))',
#        'Eggless Banoffee Ice Cream (725ml))',
#        'Eggless Banoffee Ice Cream (Family Feast (725ml))',
#        'Eggless Banoffee Ice Cream)',
#        'Eggless Cherry & Chocolate Fudge Ice Cream',
#        'Eggless Cherry & Chocolate Fudge Ice Cream (200ml))',
#        'Eggless Cherry & Chocolate Fudge Ice Cream (220gms))',
#        'Eggless Cherry & Chocolate Fudge Ice Cream (300ml))',
#        'Eggless Cherry & Chocolate Fudge Ice Cream (725ml))',
#        'Eggless Cherry & Chocolate Fudge Ice Cream (Family Feast (725ml))',
#        'Eggless Cherry & Chocolate Fudge Ice Cream)',
#        'Eggless Chocolate Ice Cream',
#        'Eggless Chocolate Ice Cream (200ml))',
#        'Eggless Chocolate Ice Cream (300ml))',
#        'Eggless Chocolate Ice Cream (700ml))',
#        'Eggless Chocolate Ice Cream (725ml))',
#        'Eggless Chocolate Ice Cream (Family Feast (725ml))',
#        'Eggless Chocolate Ice Cream)',
#        'Eggless Chocolate Overload Ice Cream',
#        'Eggless Coconut & Pineapple Ice Cream',
#        'Eggless Coconut & Pineapple Ice Cream (120gm))',
#        'Eggless Coconut & Pineapple Ice Cream (200ml))',
#        'Eggless Coconut & Pineapple Ice Cream (220gms))',
#        'Eggless Coconut & Pineapple Ice Cream (300ml))',
#        'Eggless Coconut & Pineapple Ice Cream (500gms))',
#        'Eggless Coconut & Pineapple Ice Cream (60gm))',
#        'Eggless Coconut & Pineapple Ice Cream (700ml))',
#        'Eggless Coconut & Pineapple Ice Cream (725ml))',
#        'Eggless Coconut & Pineapple Ice Cream (Navratri) (200ml))',
#        'Eggless Coconut & Pineapple Ice Cream (navratri) (300ml))',
#        'Eggless Coconut & Pineapple Ice Cream)',
#        'Eggless Coffee Mascarpone Ice Cream',
#        'Eggless Coffee Mascarpone Ice Cream (120gm))',
#        'Eggless Coffee Mascarpone Ice Cream (200ml))',
#        'Eggless Coffee Mascarpone Ice Cream (220gms))',
#        'Eggless Coffee Mascarpone Ice Cream (300ml))',
#        'Eggless Coffee Mascarpone Ice Cream (500gms))',
#        'Eggless Coffee Mascarpone Ice Cream (700ml))',
#        'Eggless Coffee Mascarpone Ice Cream (725ml))',
#        'Eggless Coffee Mascarpone Ice Cream (Family Feast (725ml))',
#        'Eggless Coffee Mascarpone Ice Cream (Family Feast)',
#        'Eggless Coffee Mascarpone Ice Cream (navratri) (300ml))',
#        'Eggless Coffee Mascarpone Ice Cream (navratri) (725ml))',
#        'Eggless Coffee Mascarpone Ice Cream)',
#        'Eggless Design Your Indulgence Duo',
#        'Eggless Fig & Orange Ice Cream',
#        'Eggless Fig & Orange Ice Cream (200ml))',
#        'Eggless Fig & Orange Ice Cream (300ml))',
#        'Eggless Fig & Orange Ice Cream (navratri) (300ml))',
#        'Eggless Just Chocolate Ice Cream',
#        'Eggless Kulfi Inspired Ice Cream',
#        'Eggless Milk Chocolate Ice Cream',
#        'Eggless Old Fashion Vanila Ice Cream',
#        'Eggless Old Fashion Vanila Ice Cream (Family Feast)',
#        'Eggless Old Fashion Vanila Ice Cream)',
#        'Eggless Paan & Gulkand Ice Cream',
#        'Eggless Paan & Gulkand Ice Cream (200ml))',
#        'Eggless Paan & Gulkand Ice Cream (220gms))',
#        'Eggless Paan & Gulkand Ice Cream (300ml))',
#        'Eggless Paan & Gulkand Ice Cream (700ml))',
#        'Eggless Paan & Gulkand Ice Cream (725ml))',
#        'Eggless Paan & Gulkand Ice Cream (Family Feast (725ml))',
#        'Eggless Paan & Gulkand Ice Cream (Family Feast)',
#        'Eggless Paan & Gulkand Ice Cream (Mini Indulgence (200ml))',
#        'Eggless Paan & Gulkand Ice Cream (navratri) (300ml))',
#        'Eggless Paan & Gulkand Ice Cream (navratri) (725ml))',
#        'Eggless Paan & Gulkand Ice Cream)',
#        'Eggless Strawberry Cream Cheese Ice Cream',
#        'Eggless Strawberry Cream Cheese Ice Cream (200ml))',
#        'Eggless Strawberry Cream Cheese Ice Cream (300ml))',
#        'Eggless Strawberry Cream Cheese Ice Cream (700ml))',
#        'Eggless Strawberry Cream Cheese Ice Cream (725ml))',
#        'Eggless Strawberry Cream Cheese Ice Cream (Family Feast (725ml))',
#        'Eggless Strawberry Cream Cheese Ice Cream (Family Feast)',
#        'Eggless Strawberry Cream Cheese Ice Cream (Mini Indulgence (200ml))',
#        'Eggless Strawberry Cream Cheese Ice Cream (navratri) (300ml))',
#        'Eggless Strawberry Cream Cheese Ice Cream (navratri) (725ml))',
#        'Eggless Strawberry Cream Cheese Ice Cream)',
#        'Employee Dessert ( Any 1 )', 'Fig & Orange Ice Cream',
#        'Fig & Orange Ice Cream (120gm))',
#        'Fig & Orange Ice Cream (200ml))',
#        'Fig & Orange Ice Cream (220gms))',
#        'Fig & Orange Ice Cream (300ml))',
#        'Fig & Orange Ice Cream (500gms))',
#        'Fig & Orange Ice Cream (60gm))',
#        'Fig & Orange Ice Cream (725ml))',
#        'Fig & Orange Ice Cream (Family Feast (550gms))',
#        'Fig & Orange Ice Cream (Family Feast (725ml))',
#        'Fig & Orange Ice Cream (Regular)', 'Fig & Orange Ice Cream)',
#        'Go Bananas Ice Cream',
#        'Go Bananas Ice Cream (Family Feast (550gms))', 'Hot Chocolate',
#        'Hot Chocolate Fudge Sauce (250gm)', 'Ice Cream Cake 1kg',
#        'Ice Cream Cake 400gm',
#        'Ice Cream Factory Visit & Trials (single)',
#        'Ice Cream Factory Visit & Trials(family)',
#        'Just Chocolate Ice Cream', 'Just Chocolate Ice Cream (120gm))',
#        'Just Chocolate Ice Cream (220gms))',
#        'Just Chocolate Ice Cream (500gms))',
#        'Just Chocolate Ice Cream (60gm))', 'Just Chocolate Ice Cream)',
#        'Large Box Thermocol And Dry Ice Packaging',
#        'Masala Chai Ice Cream', 'Masala Chai Ice Cream (120gm))',
#        'Masala Chai Ice Cream (200ml))',
#        'Masala Chai Ice Cream (220gms))',
#        'Masala Chai Ice Cream (300ml))', 'Masala Chai Ice Cream (700ml))',
#        'Masala Chai Ice Cream)',
#        'Mocha Indulgence Duo Ice Creams (200ml + 200ml)',
#        'Monkey Business Ice Cream', 'Monkey Business Ice Cream (120gm))',
#        'Monkey Business Ice Cream (200ml))',
#        'Monkey Business Ice Cream (220gms))',
#        'Monkey Business Ice Cream (300ml))',
#        'Monkey Business Ice Cream (500gms))',
#        'Monkey Business Ice Cream (60gm))',
#        'Monkey Business Ice Cream (700ml))',
#        'Monkey Business Ice Cream (725ml))',
#        'Monkey Business Ice Cream (Family Feast (550gms))',
#        'Monkey Business Ice Cream (Family Feast (725ml))',
#        'Monkey Business Ice Cream (Family Feast)',
#        'Monkey Business Ice Cream)',
#        'Nona’s Traditional Plum Cake Contains Alcohol',
#        'Old Fashion Vanilla Ice Cream',
#        'Old Fashion Vanilla Ice Cream (120gm))',
#        'Old Fashion Vanilla Ice Cream (200ml))',
#        'Old Fashion Vanilla Ice Cream (220gms))',
#        'Old Fashion Vanilla Ice Cream (300ml))',
#        'Old Fashion Vanilla Ice Cream (500gms))',
#        'Old Fashion Vanilla Ice Cream (60gm))',
#        'Old Fashion Vanilla Ice Cream (700ml))',
#        'Old Fashion Vanilla Ice Cream (725ml))',
#        'Old Fashion Vanilla Ice Cream (Family Feast (725ml))',
#        'Old Fashion Vanilla Ice Cream (Family Feast)',
#        'Old Fashion Vanilla Ice Cream (Regular)',
#        'Old Fashion Vanilla Ice Cream (Scoop)',
#        'Old Fashion Vanilla Ice Cream)',
#        'Orange & Biscuits (with Alcohol)',
#        'Orange Ice Cream (with Alcohol) (120gm))',
#        'Orange Ice Cream (with Alcohol) (220gms))',
#        'Orange Ice Cream (with Alcohol))', 'Paan & Gulkand Ice Cream',
#        'Paan & Gulkand Ice Cream (120gm))',
#        'Paan & Gulkand Ice Cream (200ml))',
#        'Paan & Gulkand Ice Cream (220gms))',
#        'Paan & Gulkand Ice Cream (300ml))',
#        'Paan & Gulkand Ice Cream (500gms))',
#        'Paan & Gulkand Ice Cream (60gm))', 'Paan & Gulkand Ice Cream)',
#        'Pistachio Ice Cream', 'Pistachio Ice Cream (120gm))',
#        'Pistachio Ice Cream (200ml))', 'Pistachio Ice Cream (220gms))',
#        'Pistachio Ice Cream (300ml))', 'Pistachio Ice Cream (500gms))',
#        'Pistachio Ice Cream (700ml))', 'Pistachio Ice Cream (725ml))',
#        'Pistachio Ice Cream (Family Feast (725ml))',
#        'Pistachio Ice Cream (Family Feast)',
#        'Pistachio Ice Cream (Regular)', 'Pistachio Ice Cream)',
#        'Rose Cardamom Ice Cream', 'Rose Cardamom Ice Cream (120gm))',
#        'Rose Cardamom Ice Cream (200ml))',
#        'Rose Cardamom Ice Cream (220gms))',
#        'Rose Cardamom Ice Cream (300ml))',
#        'Rose Cardamom Ice Cream (700ml))',
#        'Rose Cardamom Ice Cream (725ml))',
#        'Rose Cardamom Ice Cream (Family Feast (725ml))',
#        'Rose Cardamom Ice Cream)', 'School Kids Factor Visit',
#        'Special Packaging Dryice Charges',
#        'Special Packaging Thermocol Charges',
#        'Strawberry Cream Cheese Ice Cream',
#        'Strawberry Cream Cheese Ice Cream (120gm))',
#        'Strawberry Cream Cheese Ice Cream (200ml))',
#        'Strawberry Cream Cheese Ice Cream (220gms))',
#        'Strawberry Cream Cheese Ice Cream (300ml))',
#        'Strawberry Cream Cheese Ice Cream (500gms))',
#        'Strawberry Cream Cheese Ice Cream (60gm))',
#        'Strawberry Cream Cheese Ice Cream)', 'Sunshine Limone Ice Cream',
#        'Sunshine Limone Ice Cream (120gm))',
#        'Sunshine Limone Ice Cream (200ml))',
#        'Sunshine Limone Ice Cream (220gms))',
#        'Sunshine Limone Ice Cream (300ml))',
#        'Sunshine Limone Ice Cream (60gm))',
#        'Sunshine Limone Ice Cream (700ml))',
#        'Sunshine Limone Ice Cream (725ml))',
#        'Sunshine Limone Ice Cream (Family Feast (550gms))',
#        'Sunshine Limone Ice Cream (Family Feast (725ml))',
#        'Sunshine Limone Ice Cream)', 'Tres Leches',
#        'Triple Chocolate Ice Cream',
#        'Triple Chocolate Ice Cream (200ml))',
#        'Triple Chocolate Ice Cream (Family Feast (725ml))',
#        'Triple Chocolate Ice Cream (Family Feast)',
#        'Triple Chocolate Ice Cream (Scoop)',
#        'Triple Chocolate Ice Cream)', 'Water Bottle'], dtype=object)

# %%
df['type'].unique()
# Out:
# array(['Ice Cream', 'Dessert', 'Extra', 'Combo'], dtype=object)
