# %%
import re
import csv
from typing import Dict, List, Set, Tuple

# ============================================================
# CONSTANTS
# ============================================================

# Drinks
# Drinks
DRINKS = {
    'Americano',
    'Cappuccino',
    'Hot Chocolate',
    'Water Bottle',
}

# Extras
EXTRAS_PATTERNS = [
    'Cup',
    'Takeaway Cup', 
    'Waffle Cone',
    'Butter Waffle',
    'Delivery Charges',
    'Pidge/Porter',
    'Packaging',
    'Thermocol',
    'Dry Ice',
    'Hot Chocolate Fudge Sauce',
]

# Desserts
DESSERTS_PATTERNS = [
    'Affogato',
    'Boston Cream Pie',
    'Brownie',
    'Cheesecake',
    'Lamington',
    'Tiramisu',
    'Plum Cake',
    'Cookie',
    'Tres Leches',
    'Employee Dessert',
    'Cream Cheese Fruit Medley Cake',
    'Ice Cream Cake',
    'Customised Ice Cream Cake',
]

# Combos
COMBOS_PATTERNS = [
    'Duo',
    'Family Pack',
    'Half In Half',
    'Combo',
]

# Services
SERVICES_PATTERNS = [
    'Factory Visit',
    'School Kids',
]

# ============================================================
# HELPER FUNCTIONS
# ============================================================

def fix_html_entities(text: str) -> str:
    """Fix HTML entities"""
    return text.replace('&amp;', '&')


def fix_typos(name: str) -> str:
    """Fix common typos"""
    # Fix Piec -> Pie
    name = re.sub(r'\bPiec\b', 'Pie', name)
    # Fix Vanila -> Vanilla
    name = re.sub(r'\bVanila\b', 'Vanilla', name)
    # Fix Alphanso -> Alphonso
    name = re.sub(r'\bAlphanso\b', 'Alphonso', name)
    # Fix Factor -> Factory (School Kids Factor Visit)
    name = re.sub(r'\bFactor Visit\b', 'Factory Visit', name)
    # Fix Pidge/porter -> Pidge/Porter
    name = re.sub(r'Pidge/porter', 'Pidge/Porter', name)
    # Standardize Bean-to-bar capitalization
    name = re.sub(r'\bBean-to-bar\b', 'Bean-to-Bar', name, flags=re.IGNORECASE)
    name = re.sub(r'\bBean To Bar\b', 'Bean-to-Bar', name, flags=re.IGNORECASE)
    # Fix "Chocolate Dark" -> "Dark Chocolate"
    name = re.sub(r'\bChocolate Dark\b', 'Dark Chocolate', name)
    name = re.sub(r'\bChocolate 70% Dark\b', '70% Dark Chocolate', name)
    # Fix D&n -> D&N
    name = re.sub(r'\bD&n\b', 'D&N', name)
    # Standardize "contains Alcohol" -> "(Contains Alcohol)"
    name = re.sub(r'\(contains Alcohol\)', '(Contains Alcohol)', name, flags=re.IGNORECASE)
    name = re.sub(r'With Alcohol', '(Contains Alcohol)', name, flags=re.IGNORECASE)
    name = re.sub(r'\(with Alcohol\)', '(Contains Alcohol)', name, flags=re.IGNORECASE)
    # Fix "Fig Orange" -> "Fig & Orange"
    name = re.sub(r'\bFig Orange\b', 'Fig & Orange', name)
    # Fix Eggles -> Eggless
    name = re.sub(r'\bEggles\b', 'Eggless', name)
    return name


def extract_variant(raw_name: str) -> Tuple[str, str]:
    """Extract variant from raw name and return (clean_name, variant)"""
    name = raw_name
    name_lower = name.lower()
    
    # Special single-item patterns
    if 'any 1' in name_lower:
        return name.strip(), '1_PIECE'
    
    # Combo patterns first
    if '200ml+200ml' in name_lower or '200ml + 200ml' in name_lower:
        name = re.sub(r'\s*\(200ml\s*\+\s*200ml\)', '', name, flags=re.IGNORECASE)
        return name.strip(), 'DUO_200ML_200ML'
    
    if '200+200+200' in name_lower:
        name = re.sub(r'\s*\(200\+200\+200[^)]*\)', '', name, flags=re.IGNORECASE)
        return name.strip(), 'FAMILY_PACK_3X200ML'
    
    # Size patterns with nested parentheses like "(Perfect Plenty (300ml))"
    # Family Feast patterns
    if 'family feast' in name_lower:
        if '725ml' in name_lower:
            variant = 'FAMILY_TUB_725ML'
        elif '700ml' in name_lower:
            variant = 'FAMILY_TUB_700ML'
        elif '550gms' in name_lower or '550gm' in name_lower:
            variant = 'FAMILY_TUB_550GMS'
        else:
            variant = 'FAMILY_TUB_725ML'
        name = re.sub(r'\s*\(Family Feast\s*\([^)]+\)\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'\s*\(Family Feast\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Family Tub patterns
    if 'family tub' in name_lower:
        if '725ml' in name_lower:
            variant = 'FAMILY_TUB_725ML'
        elif '700ml' in name_lower:
            variant = 'FAMILY_TUB_700ML'
        elif '500gms' in name_lower or '500gm' in name_lower:
            variant = 'FAMILY_TUB_500GMS'
        else:
            variant = 'FAMILY_TUB_500GMS'
        name = re.sub(r'\s*\(Family Tub\s*\([^)]+\)\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'\s*\(Family Tub\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Perfect Plenty patterns
    if 'perfect plenty' in name_lower:
        if '350ml' in name_lower:
            variant = 'PERFECT_PLENTY_350ML'
        elif '325ml' in name_lower:
            variant = 'PERFECT_PLENTY_325ML'
        elif '300ml' in name_lower:
            variant = 'PERFECT_PLENTY_300ML'
        elif '200ml' in name_lower:
            variant = 'PERFECT_PLENTY_200ML'
        elif '200gms' in name_lower or '200gm' in name_lower:
            variant = 'PERFECT_PLENTY_200GMS'
        else:
            variant = 'PERFECT_PLENTY_200GMS'
        name = re.sub(r'\s*\(Perfect Plenty\s*\([^)]+\)\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'\s*\(Perfect Plenty\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Mini Indulgence patterns
    if 'mini indulgence' in name_lower:
        variant = 'MINI_TUB_200ML'
        name = re.sub(r'\s*\(Mini Indulgence\s*\([^)]+\)\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'\s*\(Mini Indulgence\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Regular Tub patterns
    if 'regular tub' in name_lower:
        if '300ml' in name_lower:
            variant = 'REGULAR_TUB_300ML'
        elif '220gms' in name_lower or '220gm' in name_lower:
            variant = 'REGULAR_TUB_220GMS'
        else:
            variant = 'REGULAR_TUB_220GMS'
        name = re.sub(r'\s*\(Regular Tub\s*\([^)]+\)\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'\s*\(Regular Tub\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Mini Tub patterns
    if 'mini tub' in name_lower:
        if '200ml' in name_lower:
            variant = 'MINI_TUB_200ML'
        elif '160gms' in name_lower or '160gm' in name_lower:
            variant = 'MINI_TUB_160GMS'
        else:
            variant = 'MINI_TUB_160GMS'
        name = re.sub(r'\s*\(Mini [Tt]ub\s*\([^)]+\)\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'\s*\(Mini [Tt]ub\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Regular Scoop patterns
    if 'regular scoop' in name_lower:
        variant = 'REGULAR_SCOOP_120GMS'
        name = re.sub(r'\s*\(Regular Scoop\s*\([^)]+\)\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'\s*\(Regular Scoop\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Junior Scoop patterns
    if 'junior scoop' in name_lower:
        variant = 'JUNIOR_SCOOP_60GMS'
        name = re.sub(r'\s*\(Junior Scoop\s*\([^)]+\)\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'\s*\(Junior Scoop\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Scoop alone
    if re.search(r'\(Scoop\)', name, flags=re.IGNORECASE):
        variant = 'REGULAR_SCOOP_120GMS'
        name = re.sub(r'\s*\(Scoop\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Regular alone (like "Alphonso Mango Ice Cream (Regular)")
    if re.search(r'\(Regular\)$', name, flags=re.IGNORECASE):
        variant = 'REGULAR_SCOOP_120GMS'
        name = re.sub(r'\s*\(Regular\)$', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Piece counts
    if re.search(r'\(2\s*pc[s]?\)', name_lower) or '(2pcs)' in name_lower:
        variant = '2_PIECES'
        name = re.sub(r'\s*\(2\s*pc[s]?\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'Dessert$', '', name).strip()  # Remove "Dessert" suffix
        return name.strip(), variant
    
    if re.search(r'\(1\s*pc[s]?\)', name_lower) or '(1pcs)' in name_lower or '(1pc)' in name_lower:
        variant = '1_PIECE'
        name = re.sub(r'\s*\(1\s*pc[s]?\)', '', name, flags=re.IGNORECASE)
        name = re.sub(r'Dessert$', '', name).strip()
        return name.strip(), variant
    
    # Weight patterns standalone
    if re.search(r'\(250gm\)', name_lower):
        variant = '250GMS'
        name = re.sub(r'\s*\(250gm\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    if re.search(r'\(310gm\)', name_lower):
        variant = '310GMS'
        name = re.sub(r'\s*\(310gm\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    if re.search(r'\(325gm\)', name_lower):
        variant = '325GMS'
        name = re.sub(r'\s*\(325gm\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Size patterns like "(400gm)" or "(1kg)"
    if '1kg' in name_lower:
        variant = '1KG'
        name = re.sub(r'\s*1kg', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    if '400gm' in name_lower:
        variant = '400GMS'
        name = re.sub(r'\s*400gm', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Factory visit patterns
    if 'single' in name_lower:
        variant = 'SINGLE'
        name = re.sub(r'\s*\(single\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    if 'family' in name_lower and 'factory visit' in name_lower:
        variant = 'FAMILY'
        name = re.sub(r'\s*\(family\)', '', name, flags=re.IGNORECASE)
        return name.strip(), variant
    
    # Remove Navratri tags
    name = re.sub(r'\s*\(navratri\)', '', name, flags=re.IGNORECASE)
    name = re.sub(r'\s*\(Navratri\)', '', name, flags=re.IGNORECASE)
    
    # Small Scoop patterns
    if 'small scoop' in name_lower:
        variant = 'JUNIOR_SCOOP_60GMS'
        name = re.sub(r'\s*Small Scoop', '', name, flags=re.IGNORECASE)
        # Clean up any trailing "Ice Cream" if it was strictly part of the scoop name logic
        # But usually we keep "Ice Cream" as part of the item name.
        return name.strip(), variant
        
    # Standalone weight patterns (often in parens or just at end)
    # (160gm) or 160gm
    if '160gm' in name_lower:
        variant = 'MINI_TUB_160GMS'
        name = re.sub(r'\s*\(?160gm\)?', '', name, flags=re.IGNORECASE)
        return name.strip(), variant

    if '200ml' in name_lower:
        variant = 'MINI_TUB_200ML'
        name = re.sub(r'\s*\(?200ml\)?', '', name, flags=re.IGNORECASE)
        return name.strip(), variant

    # Default
    return name.strip(), '1_PIECE'


def determine_type(name: str) -> str:
    """Determine item type"""
    name_lower = name.lower()
    
    # Check drinks first (exact match)
    for drink in DRINKS:
        if name == drink:
            return 'Drinks'
    
    # Services
    for pattern in SERVICES_PATTERNS:
        if pattern.lower() in name_lower:
            return 'Service'
    
    # Extras
    for pattern in EXTRAS_PATTERNS:
        if pattern.lower() in name_lower:
            return 'Extra'
    
    # Desserts (but not ice cream desserts)
    if 'ice cream' not in name_lower:
        for pattern in DESSERTS_PATTERNS:
            if pattern.lower() in name_lower:
                return 'Dessert'
    
    # Combos
    for pattern in COMBOS_PATTERNS:
        if pattern.lower() in name_lower:
            return 'Combo'
    
    # Default to Ice Cream
    return 'Ice Cream'


def normalize_name(name: str) -> str:
    """Final name normalization"""
    # Remove (eggless) from name if it appears in parentheses at end
    name = re.sub(r'\s*\(eggless\)\s*', ' Eggless ', name, flags=re.IGNORECASE)
    
    # Remove "Dessert" suffix from Boston Cream Pie
    if 'Boston Cream Pie' in name:
        name = re.sub(r'\s*Dessert$', '', name)
    
    # Clean up "Contains Alcohol" positioning
    if '(Contains Alcohol)' in name and 'Ice Cream' in name:
        # Move to correct position
        name = name.replace('(Contains Alcohol) Ice Cream', 'Ice Cream (Contains Alcohol)')
        name = name.replace('Ice Cream (Contains Alcohol)', '(Contains Alcohol) Ice Cream')
    
    # Clean Chocolate & Orange naming
    if 'Chocolate & Orange' in name and 'Contains Alcohol' in name:
        name = 'Chocolate & Orange (Contains Alcohol) Ice Cream'
    
    if 'Orange Ice Cream' in name and 'Alcohol' in name and 'Chocolate' not in name:
        name = 'Orange (Contains Alcohol) Ice Cream'
    
    if 'Orange & Biscuits' in name and 'Alcohol' in name:
        name = 'Orange & Biscuits (Contains Alcohol) Ice Cream'
    
    # Remove round shape description
    name = re.sub(r'\s*-\s*Round Shape', '', name)
    
    # Clean up extra whitespace
    name = re.sub(r'\s+', ' ', name).strip()
    
    return name


def process_item(raw_name: str) -> Dict[str, str]:
    """Process a single item and return cleaned data"""
    # Step 1: Fix HTML entities
    name = fix_html_entities(raw_name)
    
    # Step 2: Fix typos
    name = fix_typos(name)
    
    # Step 3: Extract variant
    name, variant = extract_variant(name)
    
    # Step 4: Determine type
    item_type = determine_type(name)
    
    # Step 5: Normalize name
    name = normalize_name(name)
    
    # Handle special variants for specific types
    if item_type == 'Drinks':
        variant = '1_PIECE'
    
    if item_type == 'Combo' and variant == '1_PIECE':
        if 'Duo' in name:
            variant = 'DUO_200ML_200ML'
        elif 'Family Pack' in name or 'Pack Of 3' in name:
            variant = 'FAMILY_PACK_3X200ML'
        elif 'Half In Half' in name:
            variant = 'HALF_IN_HALF_REGULAR_SCOOP'
    
    return {
        'name': name,
        'type': item_type,
        'variant': variant,
    }

# %%
import requests
import json
import html
import re
from typing import Optional, List, Dict, Any

BASE_URL = "https://webhooks.db1-prod-dachnona.store/analytics"
API_KEY = "f3e1753aa4c44159fa7218a31cd8db1e"

HEADERS = {
    "X-API-Key": API_KEY,
}

def _safe_json_load(value):
    if value is None:
        return None
    if isinstance(value, (dict, list)):
        return value
    try:
        return json.loads(value)
    except (TypeError, ValueError):
        return value

def fetch_stream_raw(
    endpoint: str,
    limit: int = 500,
    start_cursor: Optional[int] = 0,
) -> List[Dict[str, Any]]:
    results = []
    last_stream_id = start_cursor or 0

    while True:
        params = {
            "limit": limit,
            "cursor": last_stream_id,
        }

        resp = requests.get(
            f"{BASE_URL}/{endpoint}/",
            headers=HEADERS,
            params=params,
            timeout=60,
        )
        resp.raise_for_status()

        payload = resp.json()
        batch = payload.get("data", [])

        if not batch:
            break

        results.extend(batch)
        last_stream_id = batch[-1]["stream_id"]

        if len(batch) < limit:
            break

    return results

records = fetch_stream_raw("orders")

menu_list = []
for record in records:
    item_lst = record['raw_event']['raw_payload']['properties']['OrderItem']
    for item in item_lst:
        menu_list.append(item['name'])
        for addon in item['addon']:
            menu_list.append(addon['name'])

# %%
menu_list = []
for record in records:
    item_lst = record['raw_event']['raw_payload']['properties']['OrderItem']
    for item in item_lst:
        menu_list.append(item['name'])
        for addon in item['addon']:
            menu_list.append(addon['name'])   
            
cleaned_list = []
for raw_name in menu_list:
    if not raw_name:
        continue
    cleaned_list.append(process_item(raw_name))

# %%
# Create DataFrame
df_duplicate = pd.DataFrame(cleaned_list)
# Remove duplicate rows
df = df_duplicate.drop_duplicates()
df
# Out:
#                                            name       type  \
# 0      Bean-to-Bar 70% Dark Chocolate Ice Cream  Ice Cream
# 1                     Monkey Business Ice Cream  Ice Cream
# 2                     Monkey Business Ice Cream  Ice Cream
# 3                              Boston Cream Pie    Dessert
# 4                   Eggless Chocolate Ice Cream  Ice Cream
# ...                                         ...        ...
# 12770          Curious Creations Duo Ice Creams      Combo
# 12878        Classic Night & Day Duo Ice Creams      Combo
# 12928                     Masala Chai Ice Cream  Ice Cream
# 12997     Eggless Old Fashion Vanilla Ice Cream  Ice Cream
# 13303                             Hot Chocolate     Drinks
#
#                     variant
# 0      PERFECT_PLENTY_300ML
# 1      PERFECT_PLENTY_300ML
# 2         REGULAR_TUB_300ML
# 3                  2_PIECES
# 4         REGULAR_TUB_300ML
# ...                     ...
# 12770       DUO_200ML_200ML
# 12878       DUO_200ML_200ML
# 12928    JUNIOR_SCOOP_60GMS
# 12997      FAMILY_TUB_725ML
# 13303               1_PIECE
#
# [368 rows x 3 columns]

# %%
df[df['name'] == 'Hot Chocolate']
# Out:
#                 name       type  variant
# 13303  Hot Chocolate  Ice Cream  1_PIECE

# %%
df[df['type'] == 'Drinks']['name'].unique()
# Out:
# array(['Water Bottle', 'Cappuccino', 'Americano', 'Hot Chocolate'],
#       dtype=object)

# %%
df['type'].unique()
# Out:
# array(['Ice Cream', 'Dessert', 'Combo', 'Extra', 'Drinks', 'Service'],
#       dtype=object)

# %%
set(menu_list)
# Out:
# {'400 Pidge/porter Delivery Charges',
#  '500 Pidge/porter Delivery Charges',
#  'Affogato',
#  'Alphonso Mango Ice Cream (Perfect Plenty (200gms))',
#  'Alphonso Mango Ice Cream (Regular)',
#  'Americano',
#  'Assorted Cookie Duo ( Dark Chocolate (1pc) + Choco Chip (1pc) )',
#  'Banoffee Ice Cream (160gm)',
#  'Banoffee Ice Cream (Family Tub (500gms))',
#  'Banoffee Ice Cream (Junior Scoop (60gm))',
#  'Banoffee Ice Cream (Mini Tub (160gms))',
#  'Banoffee Ice Cream (Mini tub (160gms))',
#  'Banoffee Ice Cream (Regular Scoop (120gm))',
#  'Banoffee Ice Cream (Regular Tub (220gms))',
#  'Bean To Bar Dark Chocolate Ice Cream Small Scoop',
#  'Bean-to-Bar 70% Dark Chocolate Ice Cream (Family Feast (725ml))',
#  'Bean-to-Bar 70% Dark Chocolate Ice Cream (Perfect Plenty (200gms))',
#  'Bean-to-Bar 70% Dark Chocolate Ice Cream (Perfect Plenty (300ml))',
#  'Bean-to-Bar 70% Dark Chocolate Ice Cream (Perfect Plenty (325ml))',
#  'Bean-to-Bar Dark Chocolate Ice Cream (Family Tub (725ml))',
#  'Bean-to-Bar Dark Chocolate Ice Cream (Regular Tub (220gms))',
#  'Bean-to-Bar Dark Chocolate Ice Cream (Regular Tub (300ml))',
#  'Bean-to-bar 70% Dark Chocolate Ice Cream (160gm)',
#  'Bean-to-bar 70% Dark Chocolate Ice Cream (Family Feast (725ml))',
#  'Bean-to-bar 70% Dark Chocolate Ice Cream (Perfect Plenty (300ml))',
#  'Bean-to-bar 70% Dark Chocolate Ice Cream 200ml',
#  'Bean-to-bar Chocolate 70% Dark Ice Cream (Mini tub (200ml))',
#  'Bean-to-bar Chocolate 70% Dark Ice Cream (Perfect Plenty (300ml))',
#  'Bean-to-bar Chocolate 70% Dark Ice Cream (Perfect Plenty)',
#  'Bean-to-bar Chocolate 70% Dark Ice Cream (Regular Scoop)',
#  'Bean-to-bar Chocolate Dark Ice Cream (Family Tub (700ml))',
#  'Bean-to-bar Chocolate Dark Ice Cream (Family Tub (725ml))',
#  'Bean-to-bar Chocolate Dark Ice Cream (Junior Scoop (60gm))',
#  'Bean-to-bar Chocolate Dark Ice Cream (Mini tub (160gms))',
#  'Bean-to-bar Chocolate Dark Ice Cream (Mini tub (200ml))',
#  'Bean-to-bar Chocolate Dark Ice Cream (Regular Scoop (120gm))',
#  'Bean-to-bar Chocolate Dark Ice Cream (Regular Scoop)',
#  'Bean-to-bar Chocolate Dark Ice Cream (Regular Tub (220gms))',
#  'Bean-to-bar Chocolate Dark Ice Cream (Regular Tub (300ml))',
#  'Bean-to-bar Dark Chocolate Ice Cream (Family Tub (500gms))',
#  'Bean-to-bar Dark Chocolate Ice Cream (Family Tub (700ml))',
#  'Bean-to-bar Dark Chocolate Ice Cream (Family Tub (725ml))',
#  'Bean-to-bar Dark Chocolate Ice Cream (Mini Tub (160gms))',
#  'Bean-to-bar Dark Chocolate Ice Cream (Regular Tub (220gms))',
#  'Bean-to-bar Dark Chocolate Ice Cream (Regular Tub (300ml))',
#  'Boston Cream Pie Dessert(2pcs)',
#  'Boston Cream Pie(1pcs)',
#  'Boston Cream Piec(2pcs)',
#  "Brownie & Vanilla Ice Cream With Fudge Sauce. It's Classic !",
#  'Brownie Cheesecake',
#  'Butter Waffle Cone (2pcs)',
#  'Butter Waffle Cones (1pcs)',
#  'Butter Waffle Cones (2pcs)',
#  'Cakes & Cookies (160gm)',
#  'Cakes & Cookies 200ml',
#  'Cakes & Cookies Ice Cream (160gm)',
#  'Cakes & Cookies Ice Cream (Family Feast (725ml))',
#  'Cakes & Cookies Ice Cream (Family Tub (700ml))',
#  'Cakes & Cookies Ice Cream (Family Tub (725ml))',
#  'Cakes & Cookies Ice Cream (Junior Scoop)',
#  'Cakes & Cookies Ice Cream (Mini Tub (160gms))',
#  'Cakes & Cookies Ice Cream (Mini tub (160gms))',
#  'Cakes & Cookies Ice Cream (Mini tub (200ml))',
#  'Cakes & Cookies Ice Cream (Perfect Plenty (300ml))',
#  'Cakes & Cookies Ice Cream (Regular Scoop (120gm))',
#  'Cakes & Cookies Ice Cream (Regular Scoop)',
#  'Cakes & Cookies Ice Cream (Regular Tub (220gms))',
#  'Cakes & Cookies Ice Cream (Regular Tub (300ml))',
#  'Cakes & Cookies Ice Cream 200ml',
#  'Cakes & Cookies Ice Cream Small Scoop',
#  'Cakes &amp; Cookies 200ml',
#  'Cakes &amp; Cookies Ice Cream (Regular Tub (300ml))',
#  'Cakes &amp; Cookies Ice Cream 200ml',
#  'Cakes &amp; Cookies Ice Cream Small Scoop',
#  'Cappuccino',
#  'Cherry & Chocolate (160gm)',
#  'Cherry & Chocolate Fudge Ice Cream (Family Tub (500gms))',
#  'Cherry & Chocolate Fudge Ice Cream (Junior Scoop (60gm))',
#  'Cherry & Chocolate Fudge Ice Cream (Mini Tub (160gms))',
#  'Cherry & Chocolate Fudge Ice Cream (Mini tub (160gms))',
#  'Cherry & Chocolate Fudge Ice Cream (Regular Scoop (120gm))',
#  'Cherry & Chocolate Fudge Ice Cream (Regular Tub (220gms))',
#  'Choco Chunk Cookie (2pcs)',
#  'Choco Chunk Cookie(1pcs)',
#  'Chocolate & Orange (contains Alcohol) (Junior Scoop (60gm))',
#  'Chocolate & Orange (contains Alcohol) (Mini Tub (160gms))',
#  'Chocolate & Orange (contains Alcohol) (Mini tub (160gms))',
#  'Chocolate & Orange (contains Alcohol) (Regular Scoop (120gm))',
#  'Chocolate & Orange (contains Alcohol) (Regular Tub (220gms))',
#  'Chocolate & Orange (contains Alcohol) Ice Cream (Mini Tub (160gms))',
#  'Chocolate & Orange (contains Alcohol) Ice Cream (Regular Tub (220gms))',
#  'Chocolate & Orange With Alcohol (160gm)',
#  'Chocolate &amp; Orange (Contains Alcohol) Ice Cream (Mini Tub (160gms))',
#  'Chocolate Overload (160gm)',
#  'Chocolate Overload (Family Tub (500gms))',
#  'Chocolate Overload (Mini Tub (160gms))',
#  'Chocolate Overload (Regular Tub (220gms))',
#  'Chocolate Overload Ice Cream (Family Tub (500gms))',
#  'Chocolate Overload Ice Cream (Mini Tub (160gms))',
#  'Chocolate Overload Ice Cream (Regular Tub (220gms))',
#  'Classic Brownie & Ice Cream With Fudge Sauce',
#  'Classic Brownie & Vanilla Ice Cream With Fudge Sauce',
#  'Classic Brownie &amp; Vanilla Ice Cream With Fudge Sauce',
#  'Classic Chocolate Lamington (1pcs)',
#  'Classic Chocolate Lamington (2pcs)',
#  'Classic Night & Day Duo Ice Creams (200ml+200ml)',
#  'Classic Night &amp; Day Duo',
#  'Classic Tiramisu',
#  'Coconut & Pineapple (160gm)',
#  'Coconut & Pineapple Ice Cream (Mini Tub (160gms))',
#  'Coconut & Pineapple Ice Cream (Regular Tub (220gms))',
#  'Coconut &amp; Pineapple (160gm)',
#  'Coconut &amp; Pineapple Ice Cream (Mini Tub (160gms))',
#  'Coffee Banana Cheesecake',
#  'Coffee Mascarpone Ice Cream (160gm)',
#  'Coffee Mascarpone Ice Cream (Family Feast (725ml))',
#  'Coffee Mascarpone Ice Cream (Family Tub (500gms))',
#  'Coffee Mascarpone Ice Cream (Family Tub (700ml))',
#  'Coffee Mascarpone Ice Cream (Family Tub (725ml))',
#  'Coffee Mascarpone Ice Cream (Junior Scoop (60gm))',
#  'Coffee Mascarpone Ice Cream (Junior Scoop)',
#  'Coffee Mascarpone Ice Cream (Mini Tub (160gms))',
#  'Coffee Mascarpone Ice Cream (Mini tub (160gms))',
#  'Coffee Mascarpone Ice Cream (Mini tub (200ml))',
#  'Coffee Mascarpone Ice Cream (Perfect Plenty (300ml))',
#  'Coffee Mascarpone Ice Cream (Perfect Plenty)',
#  'Coffee Mascarpone Ice Cream (Regular Scoop (120gm))',
#  'Coffee Mascarpone Ice Cream (Regular Scoop)',
#  'Coffee Mascarpone Ice Cream (Regular Tub (220gms))',
#  'Coffee Mascarpone Ice Cream (Regular Tub (300ml))',
#  'Coffee Mascarpone Ice Cream 200ml',
#  'Coffee Mascarpone Small Scoop',
#  'Cream Cheese Fruit Medley Cake',
#  'Cup',
#  'Curious Creations Duo',
#  'Curious Creations Duo Ice Creams (200ml+200ml)',
#  'Custom Diwali Cookie Set',
#  'Customised Ice Cream Cake',
#  'D&amp;N Traditional Plum Cake (Eggless) Contains Alcohol',
#  'D&n Traditional Plum Cake (eggless) 310gm Contains Alcohol',
#  'D&n Traditional Plum Cake (eggless) 325gm Contains Alcohol',
#  'D&n Traditional Plum Cake (eggless) Contains Alcohol',
#  'Dark Double Chocolate Cookie(2pcs)',
#  'Dates & Chocolate (160gm)',
#  'Dates & Chocolate (Family Tub (500gms))',
#  'Dates & Chocolate (Junior Scoop (60gm))',
#  'Dates & Chocolate (Mini Tub (160gms))',
#  'Dates & Chocolate (Mini tub (160gms))',
#  'Dates & Chocolate (Regular Scoop (120gm))',
#  'Dates & Chocolate (Regular Tub (220gms))',
#  'Dates & Chocolate 200ml',
#  'Dates & Chocolate 200ml (eggless)',
#  'Dates & Chocolate Eggless (Family Tub (700ml))',
#  'Dates & Chocolate Eggless (Family Tub (725ml))',
#  'Dates & Chocolate Eggless (Junior Scoop)',
#  'Dates & Chocolate Eggless (Mini tub (200ml))',
#  'Dates & Chocolate Eggless (Regular Scoop)',
#  'Dates & Chocolate Eggless (Regular Tub (300ml))',
#  'Dates &amp; Chocolate Eggless (Regular Tub (300ml))',
#  'Dates &amp; Chocolate Small Scoop',
#  'Dates Rose & Nuts Ice Cream (Mini Tub (160gms))',
#  'Dates Rose & Nuts Ice Cream (Mini tub (160gms))',
#  'Dates Rose & Nuts Ice Cream (Regular Scoop (120gm))',
#  'Dates With Fig & Orange (160gm)',
#  'Dates With Fig & Orange (Family Tub (500gms))',
#  'Dates With Fig & Orange (Mini Tub (160gms))',
#  'Dates With Fig & Orange (Mini tub (160gms))',
#  'Dates With Fig & Orange (Regular Scoop (120gm))',
#  'Dates With Fig & Orange (Regular Tub (220gms))',
#  'Dates With Fig & Orange 200ml',
#  'Dates With Fig & Orange 200ml (eggless)',
#  'Dates With Fig & Orange Eggless (Family Tub (700ml))',
#  'Dates With Fig & Orange Eggless (Family Tub (725ml))',
#  'Dates With Fig & Orange Eggless (Mini tub (200ml))',
#  'Dates With Fig & Orange Eggless (Regular Scoop)',
#  'Dates With Fig & Orange Eggless (Regular Tub (300ml))',
#  'Dates With Fig &amp; Orange (Mini Tub (160gms))',
#  'Dates With Fig &amp; Orange Eggless (Regular Tub (300ml))',
#  'Dates With Fig &amp; Orange Small Scoop',
#  'Design Family Pack Of 3 Ice Creams',
#  'Design Family Pack Of 3 Ice Creams (200+200+200 Ml)',
#  'Design Your Indulgence Duo',
#  'Design Your Indulgence Duo Ice Creams (200ml+200ml)',
#  'Egg Based Paan & Gulkand Ice Cream (Mini tub (160gms))',
#  'Egg Based Paan & Gulkand Ice Cream (Regular Tub (220gms))',
#  'Egg Strawberry Cream Cheese Ice Cream (Mini tub (160gms))',
#  'Egg Strawberry Cream Cheese Ice Cream (Regular Tub (220gms))',
#  'Eggles Cherry & Chocolate 200ml',
#  'Eggles Cherry &amp; Chocolate 200ml',
#  'Eggless Alphanso Mango Ice Cream (Perfect Plenty (200gms))',
#  'Eggless Banoffee Ice Cream (Family Feast (725ml))',
#  'Eggless Banoffee Ice Cream (Family Tub (700ml))',
#  'Eggless Banoffee Ice Cream (Family Tub (725ml))',
#  'Eggless Banoffee Ice Cream (Junior Scoop)',
#  'Eggless Banoffee Ice Cream (Mini tub (200ml))',
#  'Eggless Banoffee Ice Cream (Perfect Plenty (300ml))',
#  'Eggless Banoffee Ice Cream (Regular Scoop)',
#  'Eggless Banoffee Ice Cream (Regular Tub (220gms))',
#  'Eggless Banoffee Ice Cream (Regular Tub (300ml))',
#  'Eggless Banoffee Ice Cream 200ml',
#  'Eggless Banoffee Ice Cream Small Scoop',
#  'Eggless Cherry & Chocolate 200ml',
#  'Eggless Cherry & Chocolate Ice Cream (Family Feast (725ml))',
#  'Eggless Cherry & Chocolate Ice Cream (Family Tub (725ml))',
#  'Eggless Cherry & Chocolate Ice Cream (Mini tub (200ml))',
#  'Eggless Cherry & Chocolate Ice Cream (Perfect Plenty (300ml))',
#  'Eggless Cherry & Chocolate Ice Cream (Regular Scoop)',
#  'Eggless Cherry & Chocolate Ice Cream (Regular Tub (220gms))',
#  'Eggless Cherry & Chocolate Ice Cream (Regular Tub (300ml))',
#  'Eggless Cherry & Chocolate Ice Cream Small Scoop',
#  'Eggless Cherry &amp; Chocolate 200ml',
#  'Eggless Cherry &amp; Chocolate Ice Cream (Perfect Plenty (300ml))',
#  'Eggless Cherry &amp; Chocolate Ice Cream (Regular Tub (300ml))',
#  'Eggless Cherry &amp; Chocolate Ice Cream Small Scoop',
#  'Eggless Chocolate Ice Cream (Family Feast (725ml))',
#  'Eggless Chocolate Ice Cream (Family Tub (700ml))',
#  'Eggless Chocolate Ice Cream (Family Tub (725ml))',
#  'Eggless Chocolate Ice Cream (Junior Scoop)',
#  'Eggless Chocolate Ice Cream (Mini tub (200ml))',
#  'Eggless Chocolate Ice Cream (Perfect Plenty (300ml))',
#  'Eggless Chocolate Ice Cream (Perfect Plenty (325ml))',
#  'Eggless Chocolate Ice Cream (Perfect Plenty)',
#  'Eggless Chocolate Ice Cream (Regular Scoop)',
#  'Eggless Chocolate Ice Cream (Regular Tub (300ml))',
#  'Eggless Chocolate Ice Cream 200ml',
#  'Eggless Chocolate Overload (Family Feast (725ml))',
#  'Eggless Chocolate Overload (Family Tub (500gms))',
#  'Eggless Chocolate Overload (Family Tub (700ml))',
#  'Eggless Chocolate Overload (Family Tub (725ml))',
#  'Eggless Chocolate Overload (Junior Scoop (60gm))',
#  'Eggless Chocolate Overload (Junior Scoop)',
#  'Eggless Chocolate Overload (Mini Tub (160gms))',
#  'Eggless Chocolate Overload (Mini tub (160gms))',
#  'Eggless Chocolate Overload (Mini tub (200ml))',
#  'Eggless Chocolate Overload (Perfect Plenty (300ml))',
#  'Eggless Chocolate Overload (Regular Scoop (120gm))',
#  'Eggless Chocolate Overload (Regular Scoop)',
#  'Eggless Chocolate Overload (Regular Tub (220gms))',
#  'Eggless Chocolate Overload (Regular Tub (300ml))',
#  'Eggless Chocolate Overload 200ml',
#  'Eggless Chocolate Overload Ice Cream Small Scoop',
#  'Eggless Coconut & Pineapple 200ml',
#  'Eggless Coconut & Pineapple Ice Cream (Family Tub (500gms))',
#  'Eggless Coconut & Pineapple Ice Cream (Family Tub (700ml))',
#  'Eggless Coconut & Pineapple Ice Cream (Family Tub (725ml))',
#  'Eggless Coconut & Pineapple Ice Cream (Junior Scoop (60gm))',
#  'Eggless Coconut & Pineapple Ice Cream (Mini Tub (160gms))',
#  'Eggless Coconut & Pineapple Ice Cream (Mini tub (160gms))',
#  'Eggless Coconut & Pineapple Ice Cream (Mini tub (200ml))',
#  'Eggless Coconut & Pineapple Ice Cream (Regular Scoop (120gm))',
#  'Eggless Coconut & Pineapple Ice Cream (Regular Scoop)',
#  'Eggless Coconut & Pineapple Ice Cream (Regular Tub (220gms))',
#  'Eggless Coconut & Pineapple Ice Cream (Regular Tub (300ml))',
#  'Eggless Coconut & Pineapple Ice Cream (navratri) (Regular Tub (300ml))',
#  'Eggless Coconut & Pineapple Small Scoop',
#  'Eggless Coconut &amp; Pineapple 200ml',
#  'Eggless Coconut &amp; Pineapple Ice Cream (Mini Tub (160gms))',
#  'Eggless Coconut &amp; Pineapple Ice Cream (Navratri) (Mini Tub (200ml))',
#  'Eggless Coconut &amp; Pineapple Ice Cream (Regular Scoop)',
#  'Eggless Coconut &amp; Pineapple Ice Cream (Regular Tub (300ml))',
#  'Eggless Coconut &amp; Pineapple Small Scoop',
#  'Eggless Coffee Mascarpone Ice Cream (160gm)',
#  'Eggless Coffee Mascarpone Ice Cream (Family Feast (725ml))',
#  'Eggless Coffee Mascarpone Ice Cream (Family Feast)',
#  'Eggless Coffee Mascarpone Ice Cream (Family Tub (500gms))',
#  'Eggless Coffee Mascarpone Ice Cream (Family Tub (700ml))',
#  'Eggless Coffee Mascarpone Ice Cream (Family Tub (725ml))',
#  'Eggless Coffee Mascarpone Ice Cream (Junior Scoop)',
#  'Eggless Coffee Mascarpone Ice Cream (Mini Tub (160gms))',
#  'Eggless Coffee Mascarpone Ice Cream (Mini tub (160gms))',
#  'Eggless Coffee Mascarpone Ice Cream (Mini tub (200ml))',
#  'Eggless Coffee Mascarpone Ice Cream (Perfect Plenty (200gms))',
#  'Eggless Coffee Mascarpone Ice Cream (Perfect Plenty (300ml))',
#  'Eggless Coffee Mascarpone Ice Cream (Perfect Plenty)',
#  'Eggless Coffee Mascarpone Ice Cream (Regular Scoop (120gm))',
#  'Eggless Coffee Mascarpone Ice Cream (Regular Scoop)',
#  'Eggless Coffee Mascarpone Ice Cream (Regular Tub (220gms))',
#  'Eggless Coffee Mascarpone Ice Cream (Regular Tub (300ml))',
#  'Eggless Coffee Mascarpone Ice Cream (navratri) (Family Tub (725ml))',
#  'Eggless Coffee Mascarpone Ice Cream (navratri) (Regular Tub (300ml))',
#  'Eggless Coffee Mascarpone Ice Cream 200ml',
#  'Eggless Coffee Mascarpone Ice Cream Small Scoop',
#  'Eggless Design Your Indulgence Duo',
#  'Eggless Design Your Indulgence Duo Ice Creams (200ml+200ml)',
#  'Eggless Fig & Orange 200ml',
#  'Eggless Fig & Orange Ice Cream (Regular Tub (300ml))',
#  'Eggless Fig & Orange Ice Cream (navratri) (Regular Tub (300ml))',
#  'Eggless Fig & Orange Ice Cream 200ml',
#  'Eggless Fig & Orange Ice Cream Small Scoop',
#  'Eggless Fig &amp; Orange 200ml',
#  'Eggless Fig &amp; Orange Ice Cream (Regular Tub (300ml))',
#  'Eggless Fig &amp; Orange Ice Cream Small Scoop',
#  'Eggless Fig Orange Ice Cream (Junior Scoop)',
#  'Eggless Fig Orange Ice Cream (Mini tub (200ml))',
#  'Eggless Fig Orange Ice Cream (Regular Scoop)',
#  'Eggless Fig Orange Ice Cream (Regular Tub (300ml))',
#  'Eggless Just Chocolate 200ml',
#  'Eggless Just Chocolate Small Scoop',
#  'Eggless Kulfi Inspired Ice Cream (Regular Scoop)',
#  'Eggless Milk Chocolate (Perfect Plenty)',
#  'Eggless Milk Chocolate Ice Cream 200ml',
#  'Eggless Old Fashion Vanila Ice Cream (Family Feast)',
#  'Eggless Old Fashion Vanila Ice Cream (Perfect Plenty (300ml))',
#  'Eggless Old Fashion Vanila Ice Cream (Regular Scoop)',
#  'Eggless Paan & Gulkand Ice Cream (Family Feast (725ml))',
#  'Eggless Paan & Gulkand Ice Cream (Family Feast)',
#  'Eggless Paan & Gulkand Ice Cream (Family Tub (700ml))',
#  'Eggless Paan & Gulkand Ice Cream (Family Tub (725ml))',
#  'Eggless Paan & Gulkand Ice Cream (Junior Scoop)',
#  'Eggless Paan & Gulkand Ice Cream (Mini Indulgence (200ml))',
#  'Eggless Paan & Gulkand Ice Cream (Mini tub (200ml))',
#  'Eggless Paan & Gulkand Ice Cream (Perfect Plenty (300ml))',
#  'Eggless Paan & Gulkand Ice Cream (Perfect Plenty)',
#  'Eggless Paan & Gulkand Ice Cream (Regular Scoop)',
#  'Eggless Paan & Gulkand Ice Cream (Regular Tub (220gms))',
#  'Eggless Paan & Gulkand Ice Cream (Regular Tub (300ml))',
#  'Eggless Paan & Gulkand Ice Cream (navratri) (Family Tub (725ml))',
#  'Eggless Paan & Gulkand Ice Cream (navratri) (Regular Tub (300ml))',
#  'Eggless Paan & Gulkand Ice Cream 200ml',
#  'Eggless Paan & Gulkand Ice Cream Small Scoop',
#  'Eggless Paan &amp; Gulkand Ice Cream (Perfect Plenty (200gms))',
#  'Eggless Paan &amp; Gulkand Ice Cream (Perfect Plenty (300ml))',
#  'Eggless Paan &amp; Gulkand Ice Cream 200ml',
#  'Eggless Paan &amp; Gulkand Ice Cream Small Scoop',
#  'Eggless Strawberry Cream Cheese Ice Cream (Family Feast (725ml))',
#  'Eggless Strawberry Cream Cheese Ice Cream (Family Feast)',
#  'Eggless Strawberry Cream Cheese Ice Cream (Family Tub (700ml))',
#  'Eggless Strawberry Cream Cheese Ice Cream (Family Tub (725ml))',
#  'Eggless Strawberry Cream Cheese Ice Cream (Junior Scoop)',
#  'Eggless Strawberry Cream Cheese Ice Cream (Mini Indulgence (200ml))',
#  'Eggless Strawberry Cream Cheese Ice Cream (Mini tub (200ml))',
#  'Eggless Strawberry Cream Cheese Ice Cream (Perfect Plenty (200gms))',
#  'Eggless Strawberry Cream Cheese Ice Cream (Perfect Plenty (300ml))',
#  'Eggless Strawberry Cream Cheese Ice Cream (Perfect Plenty)',
#  'Eggless Strawberry Cream Cheese Ice Cream (Regular Scoop)',
#  'Eggless Strawberry Cream Cheese Ice Cream (Regular Tub (300ml))',
#  'Eggless Strawberry Cream Cheese Ice Cream (navratri) (Family Tub (725ml))',
#  'Eggless Strawberry Cream Cheese Ice Cream (navratri) (Regular Tub (300ml))',
#  'Eggless Strawberry Cream Cheese Ice Cream 200ml',
#  'Eggless Strawberry Cream Cheese Small Scoop',
#  'Employee Dessert ( Any 1 )',
#  'Fig & Orange (160gm)',
#  'Fig & Orange 200ml',
#  'Fig & Orange Ice Cream (160gm)',
#  'Fig & Orange Ice Cream (Family Tub (500gms))',
#  'Fig & Orange Ice Cream (Junior Scoop (60gm))',
#  'Fig & Orange Ice Cream (Mini Tub (160gms))',
#  'Fig & Orange Ice Cream (Mini tub (160gms))',
#  'Fig & Orange Ice Cream (Regular Scoop (120gm))',
#  'Fig & Orange Ice Cream (Regular Tub (220gms))',
#  'Fig & Orange Ice Cream 200ml',
#  'Fig &amp; Orange 200ml',
#  'Fig &amp; Orange Ice Cream (160gm)',
#  'Fig &amp; Orange Ice Cream (Regular Tub (220gms))',
#  'Fig &amp; Orange Ice Cream 200ml',
#  'Fig &amp; Orange Ice Cream Small Scoop',
#  'Fig Orange Ice Cream (Family Feast (550gms))',
#  'Fig Orange Ice Cream (Family Feast (725ml))',
#  'Fig Orange Ice Cream (Family Tub (725ml))',
#  'Fig Orange Ice Cream (Mini tub (200ml))',
#  'Fig Orange Ice Cream (Perfect Plenty (200gms))',
#  'Fig Orange Ice Cream (Perfect Plenty (300ml))',
#  'Fig Orange Ice Cream (Perfect Plenty)',
#  'Fig Orange Ice Cream (Regular Scoop)',
#  'Fig Orange Ice Cream (Regular Tub (300ml))',
#  'Fig Orange Ice Cream (Regular)',
#  'Fudgy Chocolate Brownie',
#  'Fudgy Chocolate Brownie (1pc)',
#  'Fudgy Chocolate Brownie (2pcs) - Round Shape',
#  'Go Bananas Ice Cream (Family Feast (550gms))',
#  'Go Bananas Ice Cream (Perfect Plenty)',
#  'Go Bananas Ice Cream 200ml',
#  'Half In Half Regular Scoop Combo',
#  'Hot Chocolate',
#  'Hot Chocolate Fudge Sauce (250gm)',
#  'Ice Cream Cake 1kg',
#  'Ice Cream Cake 400gm',
#  'Ice Cream Factory Visit & Trials (single)',
#  'Ice Cream Factory Visit & Trials(family)',
#  'Just Chocolate (160gm)',
#  'Just Chocolate Ice Cream (Family Tub (500gms))',
#  'Just Chocolate Ice Cream (Junior Scoop (60gm))',
#  'Just Chocolate Ice Cream (Mini Tub (160gms))',
#  'Just Chocolate Ice Cream (Regular Scoop (120gm))',
#  'Just Chocolate Ice Cream (Regular Tub (220gms))',
#  'Large Box Thermocol And Dry Ice Packaging',
#  'Masala Chai Ice Cream (160gm)',
#  'Masala Chai Ice Cream (Family Tub (700ml))',
#  'Masala Chai Ice Cream (Mini Tub (160gms))',
#  'Masala Chai Ice Cream (Mini tub (160gms))',
#  'Masala Chai Ice Cream (Mini tub (200ml))',
#  'Masala Chai Ice Cream (Perfect Plenty (300ml))',
#  'Masala Chai Ice Cream (Regular Scoop (120gm))',
#  'Masala Chai Ice Cream (Regular Scoop)',
#  'Masala Chai Ice Cream (Regular Tub (220gms))',
#  'Masala Chai Ice Cream (Regular Tub (300ml))',
#  'Masala Chai Ice Cream 200ml',
#  'Masala Chai Ice Cream Small Scoop',
#  'Mocha Indulgence Duo Ice Creams (200ml + 200ml)',
#  'Monkey Business Ice Cream (160gm)',
#  'Monkey Business Ice Cream (Family Feast (550gms))',
#  'Monkey Business Ice Cream (Family Feast (725ml))',
#  'Monkey Business Ice Cream (Family Feast)',
#  'Monkey Business Ice Cream (Family Tub (500gms))',
#  'Monkey Business Ice Cream (Family Tub (700ml))',
#  'Monkey Business Ice Cream (Family Tub (725ml))',
#  'Monkey Business Ice Cream (Junior Scoop (60gm))',
#  'Monkey Business Ice Cream (Mini Tub (160gms))',
#  'Monkey Business Ice Cream (Mini tub (160gms))',
#  'Monkey Business Ice Cream (Mini tub (200ml))',
#  'Monkey Business Ice Cream (Perfect Plenty (300ml))',
#  'Monkey Business Ice Cream (Regular Scoop (120gm))',
#  'Monkey Business Ice Cream (Regular Scoop)',
#  'Monkey Business Ice Cream (Regular Tub (220gms))',
#  'Monkey Business Ice Cream (Regular Tub (300ml))',
#  'Monkey Business Ice Cream 200ml',
#  'Monkey Business Ice Cream Small Scoop',
#  'New York Baked Cheesecake Eggless',
#  'Nona’s Traditional Plum Cake (eggless) Contains Alcohol',
#  'Old Fashion Vanilla Ice Cream (160gm)',
#  'Old Fashion Vanilla Ice Cream (Family Feast (725ml))',
#  'Old Fashion Vanilla Ice Cream (Family Feast)',
#  'Old Fashion Vanilla Ice Cream (Family Tub (500gms))',
#  'Old Fashion Vanilla Ice Cream (Family Tub (700ml))',
#  'Old Fashion Vanilla Ice Cream (Family Tub (725ml))',
#  'Old Fashion Vanilla Ice Cream (Junior Scoop (60gm))',
#  'Old Fashion Vanilla Ice Cream (Junior Scoop)',
#  'Old Fashion Vanilla Ice Cream (Mini Tub (160gms))',
#  'Old Fashion Vanilla Ice Cream (Mini tub (160gms))',
#  'Old Fashion Vanilla Ice Cream (Mini tub (200ml))',
#  'Old Fashion Vanilla Ice Cream (Perfect Plenty (300ml))',
#  'Old Fashion Vanilla Ice Cream (Perfect Plenty)',
#  'Old Fashion Vanilla Ice Cream (Regular Scoop (120gm))',
#  'Old Fashion Vanilla Ice Cream (Regular Scoop)',
#  'Old Fashion Vanilla Ice Cream (Regular Tub (220gms))',
#  'Old Fashion Vanilla Ice Cream (Regular Tub (300ml))',
#  'Old Fashion Vanilla Ice Cream (Regular)',
#  'Old Fashion Vanilla Ice Cream (Scoop)',
#  'Old Fashion Vanilla Ice Cream 200ml',
#  'Old Fashion Vanilla Small Scoop',
#  'Orange & Biscuits (with Alcohol) (Regular Scoop)',
#  'Orange & Chocolate Cheesecake',
#  'Orange &amp; Chocolate Cheesecake',
#  'Orange Ice Cream (with Alcohol) (Mini tub (160gms))',
#  'Orange Ice Cream (with Alcohol) (Regular Scoop (120gm))',
#  'Orange Ice Cream (with Alcohol) (Regular Tub (220gms))',
#  'Paan & Gulkand Ice Cream (160gm)',
#  'Paan & Gulkand Ice Cream (Family Tub (500gms))',
#  'Paan & Gulkand Ice Cream (Junior Scoop (60gm))',
#  'Paan & Gulkand Ice Cream (Mini Tub (160gms))',
#  'Paan & Gulkand Ice Cream (Mini tub (160gms))',
#  'Paan & Gulkand Ice Cream (Mini tub (200ml))',
#  'Paan & Gulkand Ice Cream (Perfect Plenty (300ml))',
#  'Paan & Gulkand Ice Cream (Regular Scoop (120gm))',
#  'Paan & Gulkand Ice Cream (Regular Scoop)',
#  'Paan & Gulkand Ice Cream (Regular Tub (220gms))',
#  'Paan & Gulkand Ice Cream (Regular Tub (300ml))',
#  'Paan &amp; Gulkand Ice Cream (Perfect Plenty (200gms))',
#  'Pistachio Ice Cream (160gm)',
#  'Pistachio Ice Cream (Family Feast (725ml))',
#  'Pistachio Ice Cream (Family Feast)',
#  'Pistachio Ice Cream (Family Tub (500gms))',
#  'Pistachio Ice Cream (Family Tub (700ml))',
#  'Pistachio Ice Cream (Family Tub (725ml))',
#  'Pistachio Ice Cream (Junior Scoop)',
#  'Pistachio Ice Cream (Mini Tub (160gms))',
#  'Pistachio Ice Cream (Mini tub (160gms))',
#  'Pistachio Ice Cream (Mini tub (200ml))',
#  'Pistachio Ice Cream (Perfect Plenty (200gms))',
#  'Pistachio Ice Cream (Perfect Plenty (300ml))',
#  'Pistachio Ice Cream (Perfect Plenty)',
#  'Pistachio Ice Cream (Regular Scoop (120gm))',
#  'Pistachio Ice Cream (Regular Scoop)',
#  'Pistachio Ice Cream (Regular Tub (220gms))',
#  'Pistachio Ice Cream (Regular Tub (300ml))',
#  'Pistachio Ice Cream (Regular)',
#  'Pistachio Ice Cream 200ml',
#  'Pistachio Ice Cream Ice Cream Small Scoop',
#  'Rose Cardamom Ice Cream (160gm)',
#  'Rose Cardamom Ice Cream (Family Feast (725ml))',
#  'Rose Cardamom Ice Cream (Family Tub (700ml))',
#  'Rose Cardamom Ice Cream (Family Tub (725ml))',
#  'Rose Cardamom Ice Cream (Mini Tub (160gms))',
#  'Rose Cardamom Ice Cream (Mini tub (200ml))',
#  'Rose Cardamom Ice Cream (Perfect Plenty (300ml))',
#  'Rose Cardamom Ice Cream (Perfect Plenty)',
#  'Rose Cardamom Ice Cream (Regular Scoop (120gm))',
#  'Rose Cardamom Ice Cream (Regular Scoop)',
#  'Rose Cardamom Ice Cream (Regular Tub (220gms))',
#  'Rose Cardamom Ice Cream (Regular Tub (300ml))',
#  'Rose Cardamom Ice Cream 200ml',
#  'Rose Cardamom Ice Cream Small Scoop',
#  'School Kids Factor Visit',
#  'Special Packaging Dryice Charges',
#  'Special Packaging Thermocol Charges',
#  'Strawberry Cream Cheese Ice Cream (160gm)',
#  'Strawberry Cream Cheese Ice Cream (Family Tub (500gms))',
#  'Strawberry Cream Cheese Ice Cream (Junior Scoop (60gm))',
#  'Strawberry Cream Cheese Ice Cream (Mini Tub (160gms))',
#  'Strawberry Cream Cheese Ice Cream (Mini tub (160gms))',
#  'Strawberry Cream Cheese Ice Cream (Mini tub (200ml))',
#  'Strawberry Cream Cheese Ice Cream (Perfect Plenty (300ml))',
#  'Strawberry Cream Cheese Ice Cream (Perfect Plenty)',
#  'Strawberry Cream Cheese Ice Cream (Regular Scoop (120gm))',
#  'Strawberry Cream Cheese Ice Cream (Regular Scoop)',
#  'Strawberry Cream Cheese Ice Cream (Regular Tub (220gms))',
#  'Strawberry Cream Cheese Ice Cream (Regular Tub (300ml))',
#  'Sunshine Limone Ice Cream (160gm)',
#  'Sunshine Limone Ice Cream (Family Feast (550gms))',
#  'Sunshine Limone Ice Cream (Family Feast (725ml))',
#  'Sunshine Limone Ice Cream (Family Tub (700ml))',
#  'Sunshine Limone Ice Cream (Family Tub (725ml))',
#  'Sunshine Limone Ice Cream (Junior Scoop (60gm))',
#  'Sunshine Limone Ice Cream (Junior Scoop)',
#  'Sunshine Limone Ice Cream (Mini Tub (160gms))',
#  'Sunshine Limone Ice Cream (Mini tub (160gms))',
#  'Sunshine Limone Ice Cream (Mini tub (200ml))',
#  'Sunshine Limone Ice Cream (Perfect Plenty (300ml))',
#  'Sunshine Limone Ice Cream (Perfect Plenty)',
#  'Sunshine Limone Ice Cream (Regular Scoop (120gm))',
#  'Sunshine Limone Ice Cream (Regular Scoop)',
#  'Sunshine Limone Ice Cream (Regular Tub (220gms))',
#  'Sunshine Limone Ice Cream (Regular Tub (300ml))',
#  'Sunshine Limone Ice Cream 200ml',
#  'Sunshine Limone Ice Cream Small Scoop',
#  'Takeaway Cup',
#  'Tres Leches',
#  'Triple Chocolate Ice Cream (Family Feast (725ml))',
#  'Triple Chocolate Ice Cream (Family Feast)',
#  'Triple Chocolate Ice Cream (Mini tub (200ml))',
#  'Triple Chocolate Ice Cream (Perfect Plenty (200gms))',
#  'Triple Chocolate Ice Cream (Perfect Plenty (300ml))',
#  'Triple Chocolate Ice Cream (Perfect Plenty (325ml))',
#  'Triple Chocolate Ice Cream (Perfect Plenty (350ml))',
#  'Triple Chocolate Ice Cream (Perfect Plenty)',
#  'Triple Chocolate Ice Cream (Regular Scoop)',
#  'Triple Chocolate Ice Cream (Scoop)',
#  'Triple Chocolate Ice Cream 200ml',
#  'Waffle Cone',
#  'Water Bottle'}
