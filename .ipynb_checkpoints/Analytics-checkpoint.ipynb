# %%
# %load_ext autoreload
# %autoreload 2
import dachnonahelper as pj
import pandas as pd
# Out:
# /Users/kshitijsharma/Documents/projects/analytics/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
tables = pj.prepare_orders_data()

# %%
df_orders = pj.add_order_date(tables["orders"])

# %%
daily_base = pj.daily_aggregate(
    df_orders,
    metrics={
        "total_revenue": ("total", "sum"),
        "net_revenue": ("core_total", "sum"),
        "tax_collected": ("tax_total", "sum"),
        "total_orders": ("order_id", "nunique"),
    }
)
daily_channel = pj.daily_channel_revenue(df_orders)
daily_revenue_combined = (
    daily_base
    .merge(daily_channel, on="order_date", how="left")
)

# %%
daily_revenue_combined.iloc[180:220]
# Out:
#      order_date  total_revenue  net_revenue  tax_collected  total_orders  \
# 180  2025-11-26        12824.0      12980.0         610.58            22
# 181  2025-11-27        22708.0      22595.0        1081.10            31
# 182  2025-11-28        22312.0      21255.0        1062.30            28
# 183  2025-11-29        22182.0      21670.0        1056.14            35
# 184  2025-11-30        40994.0      39055.0        1951.90            49
# 185  2025-12-01        13183.0      13145.0         627.64            23
# 186  2025-12-02        11657.0      11290.0         555.04            16
# 187  2025-12-03        13928.0      13955.0         663.40            25
# 188  2025-12-04         9390.0       9545.0         447.08            17
# 189  2025-12-05        26411.0      26285.0        1257.40            39
# 190  2025-12-06        38333.0      36995.0        1825.34            49
# 191  2025-12-07        36526.0      36000.0        1739.24            54
# 192  2025-12-08         8602.0       8430.0         409.60            16
# 193  2025-12-09        12922.0      12770.0         615.26            21
# 194  2025-12-10        17543.0      17145.0         835.30            28
# 195  2025-12-11        22686.0      21655.0        1080.16            24
# 196  2025-12-12        15076.0      14970.0         717.82            26
# 197  2025-12-13        31443.0      30755.0        1496.96            49
# 198  2025-12-14        32341.0      31965.0        1539.98            52
# 199  2025-12-15        14746.0      14905.0         702.16            25
# 200  2025-12-16        26886.0      26340.0        1280.16            35
# 201  2025-12-17        16501.0      16630.0         785.64            27
# 202  2025-12-18        15008.0      14915.0         714.60            22
# 203  2025-12-19        26076.0      25565.0        1241.46            39
# 204  2025-12-20        28495.0      27675.0        1356.68            37
# 205  2025-12-21        24436.0      23135.0        1163.60            26
# 206  2025-12-22        23412.0      22595.0        1114.76            39
# 207  2025-12-23        16289.0      16500.0         775.66            29
# 208  2025-12-24        27983.0      27160.0        1332.44            36
# 209  2025-12-25        15223.0      14895.0         724.74            20
# 210  2025-12-26        20374.0      19955.0         970.22            23
# 211  2025-12-27        28130.0      27135.0        1339.46            34
# 212  2025-12-28        24157.0      23275.0        1150.40            31
# 213  2025-12-29        16345.0      16440.0         777.74            28
# 214  2025-12-30        25030.0      24015.0        1191.76            31
# 215  2025-12-31        32185.0      30925.0        1532.56            41
# 216  2026-01-01        19869.0      19610.0         945.98            35
# 217  2026-01-02        18870.0      18340.0         898.66            30
# 218  2026-01-03        19746.0      19335.0         940.12            28
#
#      Home Website      POS   Swiggy   Zomato
# 180           0.0   2017.0   3076.0   7731.0
# 181           0.0  11956.0   4784.0   5968.0
# 182           0.0   6889.0   3372.0  12051.0
# 183           0.0   4658.0   4878.0  12646.0
# 184         843.0  18531.0   6450.0  15170.0
# 185           0.0   3960.0      0.0   9223.0
# 186         798.0   5246.0   1554.0   4059.0
# 187           0.0   6607.0   2190.0   5131.0
# 188           0.0   1050.0   2222.0   6118.0
# 189         935.0   4999.0   3944.0  16533.0
# 190           0.0   9967.0   4696.0  23670.0
# 191           0.0  14465.0   7895.0  14166.0
# 192           0.0   1145.0   2883.0   4574.0
# 193           0.0   4212.0   2179.0   6531.0
# 194        2032.0   2557.0   4432.0   8522.0
# 195           0.0   3224.0   4296.0  15166.0
# 196           0.0   1780.0   5247.0   8049.0
# 197           0.0   9926.0   8520.0  12997.0
# 198           0.0  13256.0   6492.0  12593.0
# 199           0.0    368.0   5945.0   8433.0
# 200         718.0  13476.0   4123.0   8569.0
# 201        1155.0   1428.0   4276.0   9642.0
# 202        2499.0   2725.0   5636.0   4148.0
# 203           0.0   5710.0   7769.0  12597.0
# 204           0.0   2552.0  13560.0  12383.0
# 205           0.0  16797.0   2452.0   5187.0
# 206           0.0  10057.0   7762.0   5593.0
# 207           0.0   1806.0   3933.0  10550.0
# 208           0.0   9495.0   4805.0  13683.0
# 209         855.0  13874.0      0.0    494.0
# 210        1202.0   9910.0   2883.0   6379.0
# 211           0.0   5030.0   5847.0  17253.0
# 212           0.0   5828.0   5582.0  12747.0
# 213           0.0   3406.0   2264.0  10675.0
# 214           0.0   5726.0   6816.0  12488.0
# 215         791.0   6332.0   6379.0  18683.0
# 216           0.0   8079.0   5237.0   6553.0
# 217           0.0   6007.0   4195.0   8668.0
# 218           0.0   8176.0   2059.0   9511.0

# %%
from datetime import date, timedelta

def item_sales_last_n_days(
    order_items_df: pd.DataFrame,
    n_days: int
) -> pd.DataFrame:
    """
    Aggregate item sales over the last n days (inclusive of today).

    Args:
        order_items_df: normalized order_items DataFrame
        n_days: number of days to look back (n=1 means today)

    Returns:
        DataFrame with:
        - item_name
        - items_sold
        - total_sales
    """

    if n_days <= 0:
        raise ValueError("n_days must be a positive integer")

    df = order_items_df.copy()

    # ---- Validate required columns ----
    required_cols = {"name", "quantity", "total", "order_created_on"}
    missing = required_cols - set(df.columns)
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    # ---- Clean item names ----
    df["item_name"] = (
        df["name"]
        .astype(str)
        .str.strip()
        .str.lower()
    )

    # ---- Ensure datetime ----
    df["order_created_on"] = pd.to_datetime(
        df["order_created_on"], errors="coerce"
    )
    df = df[df["order_created_on"].notna()]

    # ---- Date filtering ----
    today = pd.Timestamp(date.today())
    start_date = today - pd.Timedelta(days=n_days - 1)

    df = df[
        (df["order_created_on"] >= start_date) &
        (df["order_created_on"] < today + pd.Timedelta(days=1))
    ]

    # ---- Aggregate across days ----
    result = (
        df
        .groupby("item_name", as_index=False)
        .agg(
            items_sold=("quantity", "sum"),
            total_sales=("total", "sum"),
        )
        .sort_values("items_sold", ascending=False)
    )

    return result

# %%
# Last 30 days
item_sales_last_n_days(tables["order_items"], n_days=30).reset_index(drop=True)[:15]
# Out:
#                                             item_name  items_sold  total_sales
# 0                                    classic tiramisu         290       120350
# 1                      boston cream pie dessert(2pcs)         114        46740
# 2                  classic chocolate lamington (2pcs)          91        30485
# 3                   new york baked cheesecake eggless          73        21900
# 4                                  brownie cheesecake          57        19380
# 5                       orange & chocolate cheesecake          54        18360
# 6   cherry & chocolate fudge ice cream (regular sc...          38         8575
# 7   design your indulgence duo ice creams (200ml+2...          33        19040
# 8   strawberry cream cheese ice cream (mini tub (1...          30         8680
# 9              banoffee ice cream (mini tub (160gms))          30         8800
# 10  eggless chocolate overload (regular scoop (120...          30         6825
# 11            pistachio ice cream (mini tub (160gms))          27         7510
# 12                   half in half regular scoop combo          27         6135
# 13          banoffee ice cream (regular tub (220gms))          26         9120
# 14  strawberry cream cheese ice cream (regular sco...          26         5775

# %%
tables["addons"]['addon_id'].unique()
# Out:
# array(['53392899', '53392898', '54290378', '54290380', '55242583',
#        '51975431', '51975446', '56834945', '53507747', '54897565',
#        '51949328', '51492579', '52320267', '52320273', '54012828',
#        '51492576', '51492580', '58647656', '54897517', '55826298',
#        '51975449', '51975461', '51975434', '54126527', '54012795',
#        '51217643', '51949323', '51949303', '51217654', '51949327',
#        '51217625', '59023334', '51217635', '51217623', '54290382',
#        '54290390', '54290391', '59023331', '54290381', '54290388',
#        '54290379', '56834951', '56834927', '56834952', '52700808',
#        '54897455', '59023335', '54290386', '51217631', '52962550',
#        '53120322', '56834935', '54290377', '51492577', '51492581',
#        '51492585', '51949324', '59177462', '53120312', '59177463',
#        '51217652', '51217650', '51492586', '54897457', '54290385',
#        '54290387', '54012829', '51975440', '56834924', '53120313',
#        '51492582', '52962551', '54490319', '52320277', '51975437',
#        '54290384', '54897583', '51492583', '54126528', '51975455',
#        '51975456', '51975462', '55242584', '54290615', '54897456',
#        '51975452', '51949300', '55826299', '51975435', '51975441',
#        '51975447', '53120323', '51217637', '53120328', '54440585',
#        '51975432', '51975438', '56834946', '51975458', '59177467'],
#       dtype=object)

# %%
tables["addons"][tables["addons"]['addon_id'] == '54897583']
# Out:
#      order_item_addon_id  order_item_id  order_id    order_created_on  \
# 446                  447           1346      4927 2025-12-21 22:55:25
#
#      addon_id                                     name         group_name  \
# 446  54897583  Eggless Coconut & Pineapple Small Scoop  Halfnhalf Flavors
#
#     addon_group_id price quantity sap_code
# 446        1648810     0        1

# %%
filtered = tables["order_items"][
    tables["order_items"]["name"].str.contains("employee dessert", case=False, na=False)
]

# %%
target_day = "2025-12-30"
filtered_day = tables["addons"][tables["addons"]['order_created_on'].dt.date == pd.to_datetime(target_day).date()]

# %%
filtered_day
# Out:
#      order_item_addon_id  order_item_id  order_id    order_created_on  \
# 603                  604           1811      5178 2025-12-30 16:54:16
# 604                  605           1811      5178 2025-12-30 16:54:16
# 605                  606           1811      5178 2025-12-30 16:54:16
# 606                  607           1812      5178 2025-12-30 16:54:16
# 607                  608           1812      5178 2025-12-30 16:54:16
# 608                  609           1812      5178 2025-12-30 16:54:16
# 609                  610           1817      5182 2025-12-30 19:25:43
# 610                  611           1817      5182 2025-12-30 19:25:43
# 611                  612           1817      5182 2025-12-30 19:25:43
# 612                  613           1821      5184 2025-12-30 19:42:29
# 613                  614           1822      5184 2025-12-30 19:42:29
# 614                  615           1823      5184 2025-12-30 19:42:29
# 615                  616           1824      5184 2025-12-30 19:42:29
# 616                  617           1828      5186 2025-12-30 20:20:26
# 617                  618           1829      5186 2025-12-30 20:20:26
# 618                  619           1842      5193 2025-12-30 21:16:20
# 619                  620           1842      5193 2025-12-30 21:16:20
# 620                  621           1851      5196 2025-12-30 21:42:27
# 621                  622           1852      5196 2025-12-30 21:42:27
# 622                  623           1860      5199 2025-12-30 23:03:27
# 623                  624           1861      5200 2025-12-30 23:44:43
# 624                  625           1861      5200 2025-12-30 23:44:43
# 625                  626           1862      5201 2025-12-30 23:49:40
# 626                  627           1863      5201 2025-12-30 23:49:40
#
#      addon_id                                              name  \
# 603  51975441                        Banoffee Ice Cream (160gm)
# 604  51975447  Bean-to-bar 70% Dark Chocolate Ice Cream (160gm)
# 605  54440585                            Just Chocolate (160gm)
# 606  51975432       Eggless Coffee Mascarpone Ice Cream (160gm)
# 607  51975438                  Paan & Gulkand Ice Cream (160gm)
# 608  56834946                         Dates & Chocolate (160gm)
# 609  53392899                                               Cup
# 610  54290377       Eggless Strawberry Cream Cheese Small Scoop
# 611  54290384             Sunshine Limone Ice Cream Small Scoop
# 612  59023334                         Butter Waffle Cone (2pcs)
# 613  59023334                         Butter Waffle Cone (2pcs)
# 614  59023334                         Butter Waffle Cone (2pcs)
# 615  59023334                         Butter Waffle Cone (2pcs)
# 616  53392899                                               Cup
# 617  53392899                                               Cup
# 618  51217637                 Monkey Business Ice Cream (160gm)
# 619  51217631             Old Fashion Vanilla Ice Cream (160gm)
# 620  53392898                                       Waffle Cone
# 621  53392898                                       Waffle Cone
# 622  59023334                         Butter Waffle Cone (2pcs)
# 623  51492576               Coffee Mascarpone Ice Cream (160gm)
# 624  51492577         Strawberry Cream Cheese Ice Cream (160gm)
# 625  53392898                                       Waffle Cone
# 626  53392898                                       Waffle Cone
#
#                             group_name addon_group_id price quantity sap_code
# 603  Design Family pack of 3 Ice Cream        1577233     0        1
# 604  Design Family pack of 3 Ice Cream        1577233     0        1
# 605  Design Family pack of 3 Ice Cream        1577233     0        1
# 606  Design Family pack of 3 Ice Cream        1577233     0        1
# 607  Design Family pack of 3 Ice Cream        1577233     0        1
# 608  Design Family pack of 3 Ice Cream        1577233    70        1
# 609                          Cuporcone        1616864     0        1
# 610                  Halfnhalf Flavors        1648810     0        1
# 611                  Halfnhalf Flavors        1648810     0        1
# 612                             Addons        1787503    80        1
# 613                             Addons        1787503    80        1
# 614                             Addons        1787503    80        1
# 615                             Addons        1787503    80        1
# 616                          Cuporcone        1616864     0        1
# 617                          Cuporcone        1616864     0        1
# 618         Design Your Indulgence Duo        1556260     0        1
# 619         Design Your Indulgence Duo        1556260     0        1
# 620                          Cuporcone        1616864    35        1
# 621                          Cuporcone        1616864    35        1
# 622                             Addons        1787503    80        1
# 623         Design Your Indulgence Duo        1556260     0        1
# 624         Design Your Indulgence Duo        1556260     0        1
# 625                          Cuporcone        1616864    35        1
# 626                          Cuporcone        1616864    35        1

# %%
df_orders
# Out:
#      order_id      restID  customer_id  tip       refId total   status  \
# 0        3239  1c8w7fp500            1    0  7017432773   956  Success
# 1        3240  1c8w7fp500            2    0  7017806983   890  Success
# 2        3241  1c8w7fp500            3    0  7018243036   462  Success
# 3        3242  1c8w7fp500            4    0  7018538844  1559  Success
# 4        3243  1c8w7fp500            5    0  7018588456   819  Success
# ...       ...         ...          ...  ...         ...   ...      ...
# 1203     5273  1c8w7fp500         1204  NaN         NaN  1397  Success
# 1204     5274  1c8w7fp500         1205  NaN         NaN   441  Success
# 1205     5275  1c8w7fp500         1206  NaN         NaN   851  Success
# 1206     5276  1c8w7fp500         1207  NaN         NaN   872  Success
# 1207     5277  1c8w7fp500         1208  NaN         NaN   357  Success
#
#      orderID table_no round_off  ... custom_payment_type               biller  \
# 0       3239               0.50  ...              Zomato                  NaN
# 1       3240        1      0.12  ...                                      NaN
# 2       3241        1         0  ...                                      NaN
# 3       3242              -0.26  ...              Zomato                  NaN
# 4       3243                  0  ...              Zomato                  NaN
# ...      ...      ...       ...  ...                 ...                  ...
# 1203    5273        2      0.50  ...                 NaN  biller (biller2173)
# 1204    5274        1         0  ...                 NaN  biller (biller2173)
# 1205    5275        3      0.50  ...                 NaN  biller (biller2173)
# 1206    5276        4      0.50  ...        Bill QR Code  biller (biller2173)
# 1207    5277        1         0  ...                 NaN  biller (biller2173)
#
#      comment assignee token_no order_from_id packaging_charge  \
# 0        NaN      NaN      NaN           NaN              NaN
# 1        NaN      NaN      NaN           NaN              NaN
# 2        NaN      NaN      NaN           NaN              NaN
# 3        NaN      NaN      NaN           NaN              NaN
# 4        NaN      NaN      NaN           NaN              NaN
# ...      ...      ...      ...           ...              ...
# 1203                        32                            0.0
# 1204                        33                            0.0
# 1205                        35                            0.0
# 1206                        34                            0.0
# 1207                        36                            0.0
#
#      customer_invoice_id part_payments reason
# 0                    NaN           NaN    NaN
# 1                    NaN           NaN    NaN
# 2                    NaN           NaN    NaN
# 3                    NaN           NaN    NaN
# 4                    NaN           NaN    NaN
# ...                  ...           ...    ...
# 1203                5273           NaN    NaN
# 1204                5274           NaN    NaN
# 1205                5275           NaN    NaN
# 1206                5276           NaN    NaN
# 1207                5277           NaN    NaN
#
# [1208 rows x 37 columns]

# %%
tables
# Out:
# {'restaurants':        restID                                            address     res_name  \
#  0  1c8w7fp500  House 2173, Ramgarh Dhani, Sector 67, Gurgaon\...  Dach & Nona
#
#    contact_information
#  0          7428846234  ,
#  'orders':      order_id      restID  customer_id  tip       refId total   status  \
#  0        3239  1c8w7fp500            1    0  7017432773   956  Success
#  1        3240  1c8w7fp500            2    0  7017806983   890  Success
#  2        3241  1c8w7fp500            3    0  7018243036   462  Success
#  3        3242  1c8w7fp500            4    0  7018538844  1559  Success
#  4        3243  1c8w7fp500            5    0  7018588456   819  Success
#  ...       ...         ...          ...  ...         ...   ...      ...
#  1203     5273  1c8w7fp500         1204  NaN         NaN  1397  Success
#  1204     5274  1c8w7fp500         1205  NaN         NaN   441  Success
#  1205     5275  1c8w7fp500         1206  NaN         NaN   851  Success
#  1206     5276  1c8w7fp500         1207  NaN         NaN   872  Success
#  1207     5277  1c8w7fp500         1208  NaN         NaN   357  Success
#
#       orderID table_no round_off  ... custom_payment_type               biller  \
#  0       3239               0.50  ...              Zomato                  NaN
#  1       3240        1      0.12  ...                                      NaN
#  2       3241        1         0  ...                                      NaN
#  3       3242              -0.26  ...              Zomato                  NaN
#  4       3243                  0  ...              Zomato                  NaN
#  ...      ...      ...       ...  ...                 ...                  ...
#  1203    5273        2      0.50  ...                 NaN  biller (biller2173)
#  1204    5274        1         0  ...                 NaN  biller (biller2173)
#  1205    5275        3      0.50  ...                 NaN  biller (biller2173)
#  1206    5276        4      0.50  ...        Bill QR Code  biller (biller2173)
#  1207    5277        1         0  ...                 NaN  biller (biller2173)
#
#       comment assignee token_no order_from_id packaging_charge  \
#  0        NaN      NaN      NaN           NaN              NaN
#  1        NaN      NaN      NaN           NaN              NaN
#  2        NaN      NaN      NaN           NaN              NaN
#  3        NaN      NaN      NaN           NaN              NaN
#  4        NaN      NaN      NaN           NaN              NaN
#  ...      ...      ...      ...           ...              ...
#  1203                        32                            0.0
#  1204                        33                            0.0
#  1205                        35                            0.0
#  1206                        34                            0.0
#  1207                        36                            0.0
#
#       customer_invoice_id part_payments reason
#  0                    NaN           NaN    NaN
#  1                    NaN           NaN    NaN
#  2                    NaN           NaN    NaN
#  3                    NaN           NaN    NaN
#  4                    NaN           NaN    NaN
#  ...                  ...           ...    ...
#  1203                5273           NaN    NaN
#  1204                5274           NaN    NaN
#  1205                5275           NaN    NaN
#  1206                5276           NaN    NaN
#  1207                5277           NaN    NaN
#
#  [1208 rows x 37 columns],
#  'customers':       customer_id order_id    order_created_on         name gstin phone  \
#  0               1     3239 2025-11-01 11:51:05       Shweta  None
#  1               2     3240 2025-11-01 12:52:27               None
#  2               3     3241 2025-11-01 13:40:26               None
#  3               4     3242 2025-11-01 14:12:41        ANAND  None
#  4               5     3243 2025-11-01 14:13:27  Malvi Goyal  None
#  ...           ...      ...                 ...          ...   ...   ...
#  1203         1204     5273 2026-01-01 22:53:47
#  1204         1205     5274 2026-01-01 22:59:28
#  1205         1206     5275 2026-01-01 23:02:10
#  1206         1207     5276 2026-01-01 23:02:20
#  1207         1208     5277 2026-01-01 23:47:40
#
#                                       address
#  0        Sector 109, Gurgaon Delhi NCR India
#  1
#  2
#  3                            Delhi NCR India
#  4      Sector 47, Sohna Road Delhi NCR India
#  ...                                      ...
#  1203
#  1204
#  1205
#  1206
#  1207
#
#  [1208 rows x 7 columns],
#  'order_items':       order_item_id order_id    order_created_on      itemid  \
#  0                 1     3239 2025-11-01 11:51:05  1288273819
#  1                 2     3240 2025-11-01 12:52:27  1282786652
#  2                 3     3241 2025-11-01 13:40:26  1284985206
#  3                 4     3241 2025-11-01 13:40:26  1284985315
#  4                 5     3242 2025-11-01 14:12:41  1284912158
#  ...             ...      ...                 ...         ...
#  2219           2220     5275 2026-01-01 23:02:10  1295954711
#  2220           2221     5276 2026-01-01 23:02:20  1293402169
#  2221           2222     5276 2026-01-01 23:02:20  1284985206
#  2222           2223     5276 2026-01-01 23:02:20  1285670451
#  2223           2224     5277 2026-01-01 23:47:40  1296733826
#
#                    itemcode                                               name  \
#  0         CoconutPineapple  Eggless Coconut & Pineapple Ice Cream (Family ...
#  1            FACTORYFAMILY           Ice Cream Factory Visit & Trials(family)
#  2          EgglessBanoffee         Eggless Banoffee Ice Cream (Regular Scoop)
#  3            EggLessCoffee  Eggless Coffee Mascarpone Ice Cream (Regular S...
#  4              familycombo  Design Family Pack Of 3 Ice Creams (200+200+20...
#  ...                    ...                                                ...
#  2219         fudgybrownie2       Fudgy Chocolate Brownie (2pcs) - Round Shape
#  2220    brownie cheesecake                                 Brownie Cheesecake
#  2221       EgglessBanoffee         Banoffee Ice Cream (Regular Scoop (120gm))
#  2222                Cherry  Cherry & Chocolate Fudge Ice Cream (Regular Sc...
#  2223  classic brownie & ic       Classic Brownie & Ice Cream With Fudge Sauce
#
#                     category_name quantity  price  discount    tax  total  \
#  0                           None        1    890       NaN    NaN    890
#  1                           None        1  847.5       NaN    NaN  847.5
#  2                           None        1    220       NaN    NaN    220
#  3                           None        1    220       NaN    NaN    220
#  4                           None        1    825       NaN    NaN    825
#  ...                          ...      ...    ...       ...    ...    ...
#  2219                    Desserts        1    320       0.0  16.00    320
#  2220  Gourmet Cheesecake Dessert        1    340       0.0  17.00    340
#  2221       Dach & Nona Originals        1    245       0.0  12.26    245
#  2222       Dach & Nona Originals        1    245       0.0  12.26    245
#  2223                    Desserts        1    340       0.0  17.00    340
#
#       specialnotes vendoritemcode
#  0                           None
#  1                           None
#  2                           None
#  3                           None
#  4                           None
#  ...           ...            ...
#  2219
#  2220
#  2221                      BANANA
#  2222
#  2223
#
#  [2224 rows x 14 columns],
#  'addons':      order_item_addon_id  order_item_id order_id    order_created_on  \
#  0                      1              3     3241 2025-11-01 13:40:26
#  1                      2              4     3241 2025-11-01 13:40:26
#  2                      3              5     3242 2025-11-01 14:12:41
#  3                      4              5     3242 2025-11-01 14:12:41
#  4                      5              5     3242 2025-11-01 14:12:41
#  ..                   ...            ...      ...                 ...
#  781                  782           2217     5274 2026-01-01 22:59:28
#  782                  783           2218     5275 2026-01-01 23:02:10
#  783                  784           2219     5275 2026-01-01 23:02:10
#  784                  785           2222     5276 2026-01-01 23:02:20
#  785                  786           2223     5276 2026-01-01 23:02:20
#
#       addon_id                                 name  \
#  0        None                          Waffle Cone
#  1        None                          Waffle Cone
#  2        None  Old Fashion Vanilla Ice Cream 200ml
#  3        None        Rose Cardamom Ice Cream 200ml
#  4        None     Eggless Chocolate Overload 200ml
#  ..        ...                                  ...
#  781  53392899                                  Cup
#  782  53392898                          Waffle Cone
#  783  53392898                          Waffle Cone
#  784  53392898                          Waffle Cone
#  785  53392898                          Waffle Cone
#
#                              group_name addon_group_id price quantity sap_code
#  0                            Cuporcone           None     0        1     None
#  1                            Cuporcone           None     0        1     None
#  2    Design Family Pack Of 3 Ice Cream           None     0        1     None
#  3    Design Family Pack Of 3 Ice Cream           None     0        1     None
#  4    Design Family Pack Of 3 Ice Cream           None     0        1     None
#  ..                                 ...            ...   ...      ...      ...
#  781                          Cuporcone        1616864     0        1
#  782                          Cuporcone        1616864    35        1
#  783                          Cuporcone        1616864    35        1
#  784                          Cuporcone        1616864    35        1
#  785                          Cuporcone        1616864    35        1
#
#  [786 rows x 11 columns],
#  'discounts':      discount_id order_id    order_created_on rate type  \
#  0              1     3244 2025-11-01 14:26:59    0    F
#  1              2     3253 2025-11-01 19:21:31    0    F
#  2              3     3255 2025-11-01 19:55:10    0    F
#  3              4     3256 2025-11-01 19:58:48    0    F
#  4              5     3259 2025-11-01 20:06:27    0    F
#  ..           ...      ...                 ...  ...  ...
#  509          510     5261 2026-01-01 20:41:43    0    F
#  510          511     5263 2026-01-01 21:17:42    0    F
#  511          512     5265 2026-01-01 21:30:49    0    F
#  512          513     5268 2026-01-01 21:55:56    0    F
#  513          514     5272 2026-01-01 22:45:31    0    F
#
#                                                   title amount
#  0                                     Special Discount    100
#  1                                     Special Discount    100
#  2    Reelo : Mini Tub of Any Ice Cream - Eggless Ch...      0
#  3                                     Special Discount    100
#  4                                     Special Discount    100
#  ..                                                 ...    ...
#  509                                   Special Discount    100
#  510                                   Special Discount  99.99
#  511                                   Special Discount     75
#  512                                   Special Discount  99.99
#  513                                   Special Discount    100
#
#  [514 rows x 7 columns],
#  'taxes':       tax_id order_id    order_created_on rate type     title amount
#  0          1     3239 2025-11-01 11:51:05  2.5    P  CGST@2.5  22.75
#  1          2     3239 2025-11-01 11:51:05  2.5    P  SGST@2.5  22.75
#  2          3     3240 2025-11-01 12:52:27  2.5    P  CGST@2.5  21.19
#  3          4     3240 2025-11-01 12:52:27  2.5    P  SGST@2.5  21.19
#  4          5     3241 2025-11-01 13:40:26  2.5    P  CGST@2.5     11
#  ...      ...      ...                 ...  ...  ...       ...    ...
#  2411    2412     5275 2026-01-01 23:02:10  2.5    P  SGST@2.5  20.25
#  2412    2413     5276 2026-01-01 23:02:20  2.5    P  CGST@2.5  20.75
#  2413    2414     5276 2026-01-01 23:02:20  2.5    P  SGST@2.5  20.75
#  2414    2415     5277 2026-01-01 23:47:40  2.5    P  CGST@2.5    8.5
#  2415    2416     5277 2026-01-01 23:47:40  2.5    P  SGST@2.5    8.5
#
#  [2416 rows x 7 columns]}

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Ensure correct dtypes
daily_revenue_combined["order_date"] = pd.to_datetime(daily_revenue_combined["order_date"])
daily_revenue_combined["total_revenue"] = pd.to_numeric(daily_revenue_combined["total_revenue"], errors="coerce")

# Sort from oldest to newest
daily_revenue_combined = daily_revenue_combined.sort_values("order_date")

# Plot
plt.figure(figsize=(14, 5))  # fits notebook width nicely
plt.plot(daily_revenue_combined["order_date"], daily_revenue_combined["total_revenue"], marker="o")

# Labels & title
plt.xlabel("Date")
plt.ylabel("Total Revenue")
plt.title("Daily Total Revenue Trend")

# Formatting
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()  # auto-fit everything

plt.show()

# %%
# Ensure datetime and sorting
daily_revenue_combined["order_date"] = pd.to_datetime(daily_revenue_combined["order_date"])
daily_revenue_combined = daily_revenue_combined.sort_values("order_date")

# ✅ Remove anomalies
clean_df = daily_revenue_combined[
    (daily_revenue_combined["total_revenue"] >= 10000) &
    (daily_revenue_combined["total_revenue"] <= 45000)
].copy()

# Rolling 7-day trend on cleaned data
clean_df["revenue_trend_7d"] = (
    clean_df["total_revenue"]
    .rolling(window=7, min_periods=1)
    .mean()
)

# Plot
plt.figure(figsize=(14,5))
plt.plot(clean_df["order_date"], clean_df["revenue_trend_7d"], linewidth=2)

plt.xlabel("Date")
plt.ylabel("Normalized Revenue (7-day avg)")
plt.title("Revenue Trend (7-Day Rolling Average, Anomalies Removed)")
plt.grid(alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
daily_revenue_combined["order_date"] = pd.to_datetime(daily_revenue_combined["order_date"])
daily_revenue_combined = daily_revenue_combined.sort_values("order_date")

# Mean till date (cumulative mean)
daily_revenue_combined["revenue_mean_till_date"] = (
    daily_revenue_combined["total_revenue"]
    .expanding(min_periods=1)
    .mean()
)

plt.figure(figsize=(14,5))
plt.plot(
    daily_revenue_combined["order_date"],
    daily_revenue_combined["revenue_mean_till_date"],
    linewidth=2
)

plt.xlabel("Date")
plt.ylabel("Mean Revenue Till Date")
plt.title("Revenue Trend (Cumulative Mean)")
plt.grid(alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
daily_revenue_combined["order_date"] = pd.to_datetime(daily_revenue_combined["order_date"])
daily_revenue_combined = daily_revenue_combined.sort_values("order_date")

# ✅ Remove anomalies
clean_df = daily_revenue_combined[
    (daily_revenue_combined["total_revenue"] >= 4000) &
    (daily_revenue_combined["total_revenue"] <= 50000)
].copy()

# Mean till date (cumulative mean) on filtered data
clean_df["revenue_mean_till_date"] = (
    clean_df["total_revenue"]
    .expanding(min_periods=1)
    .mean()
)

plt.figure(figsize=(14,5))
plt.plot(
    clean_df["order_date"],
    clean_df["revenue_mean_till_date"],
    linewidth=2
)

plt.xlabel("Date")
plt.ylabel("Mean Revenue Till Date")
plt.title("Revenue Trend (Cumulative Mean – Anomalies Removed)")
plt.grid(alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df = daily_revenue_combined.copy()

df["order_date"] = pd.to_datetime(df["order_date"])

# Filter after July 2025
df = df[df["order_date"] >= "2025-07-01"]

low_order_days = df[
    (df["total_orders"] >= 1) &
    (df["total_orders"] <= 5)
].sort_values("order_date")

# %%
low_order_days
# Out:
#     order_date  total_revenue  net_revenue  tax_collected  total_orders  \
# 51  2025-07-07          805.0        680.0           0.00             1
# 53  2025-07-09         5536.0       4820.0         844.38             5
# 76  2025-08-04         2425.0       2055.0         369.90             2
# 107 2025-09-08            0.0          0.0           0.00             1
#
#      Home Website     POS  Swiggy  Zomato  revenue_trend_7d  \
# 51          805.0     0.0     0.0     0.0      11078.000000
# 53            0.0     0.0   574.0  4962.0      10341.857143
# 76          708.0  1717.0     0.0     0.0      14473.542857
# 107           0.0     0.0     0.0     0.0      19964.428571
#
#      revenue_mean_till_date
# 51              5595.373077
# 53              5586.266667
# 76              8668.709091
# 107            12161.940741

# %%
df = daily_revenue_combined.copy()
df["order_date"] = pd.to_datetime(df["order_date"])

high_revenue_days = df[df["total_revenue"] > 40000]

high_revenue_days[["order_date", "total_revenue"]].sort_values("order_date")

high_revenue_days[["order_date", "total_revenue", "total_orders"]].sort_values("order_date")
# Out:
#     order_date  total_revenue  total_orders
# 100 2025-08-31        50270.0            38
# 174 2025-11-20        41121.0            28
# 177 2025-11-23        49966.0            61
# 184 2025-11-30        40994.0            49

# %%
tables['customers']
# Out:
#       customer_id order_id    order_created_on             name gstin  \
# 0               1    99999 2025-01-01 10:00:00        Test User
# 1               2       15 2025-04-30 11:53:37
# 2               3       16 2025-05-02 16:09:24     Sumeet Malik
# 3               4       17 2025-05-02 16:33:25     Sumeet Malik
# 4               5       18 2025-05-02 17:14:05   Kshitij Sharma
# ...           ...      ...                 ...              ...   ...
# 5329         5330     5343 2026-01-04 15:29:13
# 5330         5331     5344 2026-01-04 15:53:14      Anshal Jain
# 5331         5332     5345 2026-01-04 15:54:06  Paridhi Singhal
# 5332         5333     5346 2026-01-04 15:58:11           Adrita
# 5333         5334     5347 2026-01-04 17:00:28    Kriti Ganguly
#
#            phone                                            address
# 0     9999999999                                            Nowhere
# 1
# 2     7428846234
# 3     7838886234  M3M Merlin, Sector 67, Gurgaon Tower 2, Flat 7...
# 4     7428394442  Sector 10A, Near Kadipur Road House 992 (Secto...
# ...          ...                                                ...
# 5329
# 5330                          Sector 48, Sohna Road Delhi NCR India
# 5331                          Sector 48, Sohna Road Delhi NCR India
# 5332                             Sector 50, Gurgaon Delhi NCR India
# 5333                             Sector 15, Gurgaon Delhi NCR India
#
# [5334 rows x 7 columns]

# %%
df = tables['customers'].copy()
df['full_name'] = df['name'] + ' ' + df['address']

# %%
df['full_name'].nunique()
# Out:
# 2512
